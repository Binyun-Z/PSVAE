# %%
import os
import json
import time
import torch
import argparse
import numpy as np
from multiprocessing import cpu_count
from tensorboardX import SummaryWriter
from torch.utils.data import DataLoader
from collections import OrderedDict, defaultdict

from data_utlis.dataset import MyDataset
from utils import to_var, idx2word, expierment_name
from models.model import SentenceVAE

# %%
def main(args):
    ts = time.strftime('%Y-%b-%d-%H:%M:%S', time.gmtime())

    splits = ['train', 'valid'] + (['test'] if args.test else [])

    datasets = OrderedDict()
    for split in splits:
        datasets[split] = MyDataset(
            data_dir=args.data_dir,
            split=split,
            create_data=args.create_data,
            max_sequence_length=args.max_sequence_length,
            min_occ=args.min_occ
        )

    params = dict(
        vocab_size=datasets['train'].vocab_size,
        sos_idx=datasets['train'].sos_idx,
        eos_idx=datasets['train'].eos_idx,
        pad_idx=datasets['train'].pad_idx,
        unk_idx=datasets['train'].unk_idx,
        max_sequence_length=args.max_sequence_length,
        embedding_size=args.embedding_size,
        rnn_type=args.rnn_type,
        hidden_size=args.hidden_size,
        word_dropout=args.word_dropout,
        embedding_dropout=args.embedding_dropout,
        latent_size=args.latent_size,
        num_layers=args.num_layers,
        bidirectional=args.bidirectional
    )
    model = SentenceVAE(**params)

    if torch.cuda.is_available():
        model = model.cuda()

    print(model)

    if args.tensorboard_logging:
        writer = SummaryWriter(os.path.join(args.logdir, expierment_name(args, ts)))
        writer.add_text("model", str(model))
        writer.add_text("args", str(args))
        writer.add_text("ts", ts)

    save_model_path = os.path.join(args.save_model_path, ts)
    os.makedirs(save_model_path)

    with open(os.path.join(save_model_path, 'model_params.json'), 'w') as f:
        json.dump(params, f, indent=4)

    def kl_anneal_function(anneal_function, step, k, x0):
        if anneal_function == 'logistic':
            return float(1/(1+np.exp(-k*(step-x0))))
        elif anneal_function == 'linear':
            return min(1, step/x0)

    NLL = torch.nn.NLLLoss(ignore_index=datasets['train'].pad_idx, reduction='sum')
    def loss_fn(logp, target, length, mean, logv, anneal_function, step, k, x0):

        # cut-off unnecessary padding from target, and flatten
        target = target[:, :torch.max(length).item()].contiguous().view(-1)
        logp = logp.view(-1, logp.size(2))

        # Negative Log Likelihood
        NLL_loss = NLL(logp, target)

        # KL Divergence
        KL_loss = -0.5 * torch.sum(1 + logv - mean.pow(2) - logv.exp())
        KL_weight = kl_anneal_function(anneal_function, step, k, x0)

        return NLL_loss, KL_loss, KL_weight

    optimizer = torch.optim.Adam(model.parameters(), lr=args.learning_rate)

    tensor = torch.cuda.FloatTensor if torch.cuda.is_available() else torch.Tensor
    step = 0
    for epoch in range(args.epochs):

        for split in splits:

            data_loader = DataLoader(
                dataset=datasets[split],
                batch_size=args.batch_size,
                shuffle=split=='train',
                num_workers=cpu_count(),
                pin_memory=torch.cuda.is_available()
            )

            tracker = defaultdict(tensor)

            # Enable/Disable Dropout
            if split == 'train':
                model.train()
            else:
                model.eval()

            for iteration, batch in enumerate(data_loader):

                batch_size = batch['input'].size(0)

                for k, v in batch.items():
                    if torch.is_tensor(v):
                        batch[k] = to_var(v)

                # Forward pass
                logp, mean, logv, z = model(batch['input'], batch['length'])

                # loss calculation
                NLL_loss, KL_loss, KL_weight = loss_fn(logp, batch['target'],
                    batch['length'], mean, logv, args.anneal_function, step, args.k, args.x0)

                loss = (NLL_loss + KL_weight * KL_loss) / batch_size

                # backward + optimization
                if split == 'train':
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()
                    step += 1

                # bookkeepeing
                tracker['ELBO'] = torch.cat((tracker['ELBO'], loss.data.view(1, -1)), dim=0)

                if args.tensorboard_logging:
                    writer.add_scalar("%s/ELBO" % split.upper(), loss.item(), epoch*len(data_loader) + iteration)
                    writer.add_scalar("%s/NLL Loss" % split.upper(), NLL_loss.item() / batch_size,
                                      epoch*len(data_loader) + iteration)
                    writer.add_scalar("%s/KL Loss" % split.upper(), KL_loss.item() / batch_size,
                                      epoch*len(data_loader) + iteration)
                    writer.add_scalar("%s/KL Weight" % split.upper(), KL_weight,
                                      epoch*len(data_loader) + iteration)

                if iteration % args.print_every == 0 or iteration+1 == len(data_loader):
                    print("%s Batch %04d/%i, Loss %9.4f, NLL-Loss %9.4f, KL-Loss %9.4f, KL-Weight %6.3f"
                          % (split.upper(), iteration, len(data_loader)-1, loss.item(), NLL_loss.item()/batch_size,
                          KL_loss.item()/batch_size, KL_weight))

                if split == 'valid':
                    if 'target_sents' not in tracker:
                        tracker['target_sents'] = list()
                    tracker['target_sents'] += idx2word(batch['target'].data, i2w=datasets['train'].get_i2w(),
                                                        pad_idx=datasets['train'].pad_idx)
                    tracker['z'] = torch.cat((tracker['z'], z.data), dim=0)

            print("%s Epoch %02d/%i, Mean ELBO %9.4f" % (split.upper(), epoch, args.epochs, tracker['ELBO'].mean()))

            if args.tensorboard_logging:
                writer.add_scalar("%s-Epoch/ELBO" % split.upper(), torch.mean(tracker['ELBO']), epoch)

            # save a dump of all sentences and the encoded latent space
            if split == 'valid':
                dump = {'target_sents': tracker['target_sents'], 'z': tracker['z'].tolist()}
                if not os.path.exists(os.path.join('dumps', ts)):
                    os.makedirs('dumps/'+ts)
                with open(os.path.join('dumps/'+ts+'/valid_E%i.json' % epoch), 'w') as dump_file:
                    json.dump(dump,dump_file)

            # save checkpoint
            if split == 'train':
                checkpoint_path = os.path.join(save_model_path, "E%i.pytorch" % epoch)
                torch.save(model.state_dict(), checkpoint_path)
                print("Model saved at %s" % checkpoint_path)

# %%
from cfg import train_cfg

# %%
main(train_cfg)
# Out:
# Creating new TRAIN llps data.
# Vocablurary of 24 keys created.
# Creating new VALID llps data.
# SentenceVAE(
#   (embedding): Embedding(24, 256)
#   (embedding_dropout): Dropout(p=0.3, inplace=False)
#   (encoder_rnn): GRU(256, 256, batch_first=True)
#   (decoder_rnn): GRU(256, 256, batch_first=True)
#   (hidden2mean): Linear(in_features=256, out_features=64, bias=True)
#   (hidden2logv): Linear(in_features=256, out_features=64, bias=True)
#   (latent2hidden): Linear(in_features=64, out_features=256, bias=True)
#   (outputs2vocab): Linear(in_features=256, out_features=24, bias=True)
# )
# TRAIN Batch 0000/0, Loss  359.0739, NLL-Loss  359.0706, KL-Loss    1.7068, KL-Weight  0.002
# TRAIN Epoch 00/500, Mean ELBO  359.0739
# Model saved at checkpoints/2023-Dec-05-03:19:06/E0.pytorch
# VALID Batch 0000/0, Loss  342.2232, NLL-Loss  342.2192, KL-Loss    2.0669, KL-Weight  0.002
# VALID Epoch 00/500, Mean ELBO  342.2232
# TRAIN Batch 0000/0, Loss  343.7856, NLL-Loss  343.7816, KL-Loss    2.0669, KL-Weight  0.002
# TRAIN Epoch 01/500, Mean ELBO  343.7856
# Model saved at checkpoints/2023-Dec-05-03:19:06/E1.pytorch
# VALID Batch 0000/0, Loss  329.1339, NLL-Loss  329.1280, KL-Loss    3.0386, KL-Weight  0.002
# VALID Epoch 01/500, Mean ELBO  329.1339
# TRAIN Batch 0000/0, Loss  331.4571, NLL-Loss  331.4512, KL-Loss    3.0386, KL-Weight  0.002
# TRAIN Epoch 02/500, Mean ELBO  331.4571
# Model saved at checkpoints/2023-Dec-05-03:19:06/E2.pytorch
# VALID Batch 0000/0, Loss  319.3908, NLL-Loss  319.3817, KL-Loss    4.6786, KL-Weight  0.002
# VALID Epoch 02/500, Mean ELBO  319.3908
# TRAIN Batch 0000/0, Loss  321.4392, NLL-Loss  321.4301, KL-Loss    4.6786, KL-Weight  0.002
# TRAIN Epoch 03/500, Mean ELBO  321.4392
# Model saved at checkpoints/2023-Dec-05-03:19:06/E3.pytorch
# VALID Batch 0000/0, Loss  312.8694, NLL-Loss  312.8555, KL-Loss    7.1080, KL-Weight  0.002
# VALID Epoch 03/500, Mean ELBO  312.8694
# TRAIN Batch 0000/0, Loss  314.4202, NLL-Loss  314.4064, KL-Loss    7.1080, KL-Weight  0.002
# TRAIN Epoch 04/500, Mean ELBO  314.4202
# Model saved at checkpoints/2023-Dec-05-03:19:06/E4.pytorch
# VALID Batch 0000/0, Loss  308.2285, NLL-Loss  308.2078, KL-Loss   10.6512, KL-Weight  0.002
# VALID Epoch 04/500, Mean ELBO  308.2285
# TRAIN Batch 0000/0, Loss  309.3155, NLL-Loss  309.2947, KL-Loss   10.6512, KL-Weight  0.002
# TRAIN Epoch 05/500, Mean ELBO  309.3155
# Model saved at checkpoints/2023-Dec-05-03:19:06/E5.pytorch
# VALID Batch 0000/0, Loss  304.0158, NLL-Loss  303.9851, KL-Loss   15.7471, KL-Weight  0.002
# VALID Epoch 05/500, Mean ELBO  304.0158
# TRAIN Batch 0000/0, Loss  304.9651, NLL-Loss  304.9343, KL-Loss   15.7471, KL-Weight  0.002
# TRAIN Epoch 06/500, Mean ELBO  304.9651
# Model saved at checkpoints/2023-Dec-05-03:19:06/E6.pytorch
# VALID Batch 0000/0, Loss  300.1973, NLL-Loss  300.1520, KL-Loss   23.0975, KL-Weight  0.002
# VALID Epoch 06/500, Mean ELBO  300.1973
# TRAIN Batch 0000/0, Loss  300.7802, NLL-Loss  300.7349, KL-Loss   23.0975, KL-Weight  0.002
# TRAIN Epoch 07/500, Mean ELBO  300.7802
# Model saved at checkpoints/2023-Dec-05-03:19:06/E7.pytorch
# VALID Batch 0000/0, Loss  297.3424, NLL-Loss  297.2770, KL-Loss   33.2731, KL-Weight  0.002
# VALID Epoch 07/500, Mean ELBO  297.3424
# TRAIN Batch 0000/0, Loss  298.0475, NLL-Loss  297.9820, KL-Loss   33.2731, KL-Weight  0.002
# TRAIN Epoch 08/500, Mean ELBO  298.0475
# Model saved at checkpoints/2023-Dec-05-03:19:06/E8.pytorch
# VALID Batch 0000/0, Loss  295.3184, NLL-Loss  295.2286, KL-Loss   45.5904, KL-Weight  0.002
# VALID Epoch 08/500, Mean ELBO  295.3184
# TRAIN Batch 0000/0, Loss  296.1122, NLL-Loss  296.0224, KL-Loss   45.5904, KL-Weight  0.002
# TRAIN Epoch 09/500, Mean ELBO  296.1122
# Model saved at checkpoints/2023-Dec-05-03:19:06/E9.pytorch
# VALID Batch 0000/0, Loss  293.3887, NLL-Loss  293.2759, KL-Loss   57.1130, KL-Weight  0.002
# VALID Epoch 09/500, Mean ELBO  293.3887
# TRAIN Batch 0000/0, Loss  294.1592, NLL-Loss  294.0464, KL-Loss   57.1130, KL-Weight  0.002
# TRAIN Epoch 10/500, Mean ELBO  294.1592
# Model saved at checkpoints/2023-Dec-05-03:19:06/E10.pytorch
# VALID Batch 0000/0, Loss  291.0665, NLL-Loss  290.9377, KL-Loss   65.0309, KL-Weight  0.002
# VALID Epoch 10/500, Mean ELBO  291.0665
# TRAIN Batch 0000/0, Loss  291.8970, NLL-Loss  291.7682, KL-Loss   65.0309, KL-Weight  0.002
# TRAIN Epoch 11/500, Mean ELBO  291.8970
# Model saved at checkpoints/2023-Dec-05-03:19:06/E11.pytorch
# VALID Batch 0000/0, Loss  288.7725, NLL-Loss  288.6346, KL-Loss   69.4455, KL-Weight  0.002
# VALID Epoch 11/500, Mean ELBO  288.7725
# TRAIN Batch 0000/0, Loss  289.9135, NLL-Loss  289.7756, KL-Loss   69.4455, KL-Weight  0.002
# TRAIN Epoch 12/500, Mean ELBO  289.9135
# Model saved at checkpoints/2023-Dec-05-03:19:06/E12.pytorch
# VALID Batch 0000/0, Loss  286.8778, NLL-Loss  286.7341, KL-Loss   72.1884, KL-Weight  0.002
# VALID Epoch 12/500, Mean ELBO  286.8778
# TRAIN Batch 0000/0, Loss  288.0910, NLL-Loss  287.9473, KL-Loss   72.1884, KL-Weight  0.002
# TRAIN Epoch 13/500, Mean ELBO  288.0910
# Model saved at checkpoints/2023-Dec-05-03:19:06/E13.pytorch
# VALID Batch 0000/0, Loss  285.6189, NLL-Loss  285.4701, KL-Loss   74.5954, KL-Weight  0.002
# VALID Epoch 13/500, Mean ELBO  285.6189
# TRAIN Batch 0000/0, Loss  286.4708, NLL-Loss  286.3219, KL-Loss   74.5954, KL-Weight  0.002
# TRAIN Epoch 14/500, Mean ELBO  286.4708
# Model saved at checkpoints/2023-Dec-05-03:19:06/E14.pytorch
# VALID Batch 0000/0, Loss  284.3631, NLL-Loss  284.2110, KL-Loss   76.0304, KL-Weight  0.002
# VALID Epoch 14/500, Mean ELBO  284.3631
# TRAIN Batch 0000/0, Loss  285.5776, NLL-Loss  285.4255, KL-Loss   76.0304, KL-Weight  0.002
# TRAIN Epoch 15/500, Mean ELBO  285.5776
# Model saved at checkpoints/2023-Dec-05-03:19:06/E15.pytorch
# VALID Batch 0000/0, Loss  282.9212, NLL-Loss  282.7671, KL-Loss   76.8245, KL-Weight  0.002
# VALID Epoch 15/500, Mean ELBO  282.9212
# TRAIN Batch 0000/0, Loss  284.1588, NLL-Loss  284.0048, KL-Loss   76.8245, KL-Weight  0.002
# TRAIN Epoch 16/500, Mean ELBO  284.1588
# Model saved at checkpoints/2023-Dec-05-03:19:06/E16.pytorch
# VALID Batch 0000/0, Loss  281.4422, NLL-Loss  281.2868, KL-Loss   77.2741, KL-Weight  0.002
# VALID Epoch 16/500, Mean ELBO  281.4422
# TRAIN Batch 0000/0, Loss  282.5170, NLL-Loss  282.3616, KL-Loss   77.2741, KL-Weight  0.002
# TRAIN Epoch 17/500, Mean ELBO  282.5170
# Model saved at checkpoints/2023-Dec-05-03:19:06/E17.pytorch
# VALID Batch 0000/0, Loss  279.7672, NLL-Loss  279.6101, KL-Loss   77.9764, KL-Weight  0.002
# VALID Epoch 17/500, Mean ELBO  279.7672
# TRAIN Batch 0000/0, Loss  280.7122, NLL-Loss  280.5550, KL-Loss   77.9764, KL-Weight  0.002
# TRAIN Epoch 18/500, Mean ELBO  280.7122
# Model saved at checkpoints/2023-Dec-05-03:19:06/E18.pytorch
# VALID Batch 0000/0, Loss  278.2607, NLL-Loss  278.1013, KL-Loss   78.9122, KL-Weight  0.002
# VALID Epoch 18/500, Mean ELBO  278.2607
# TRAIN Batch 0000/0, Loss  279.4705, NLL-Loss  279.3111, KL-Loss   78.9122, KL-Weight  0.002
# TRAIN Epoch 19/500, Mean ELBO  279.4705
# Model saved at checkpoints/2023-Dec-05-03:19:06/E19.pytorch
# VALID Batch 0000/0, Loss  276.8459, NLL-Loss  276.6843, KL-Loss   79.7957, KL-Weight  0.002
# VALID Epoch 19/500, Mean ELBO  276.8459
# TRAIN Batch 0000/0, Loss  277.6727, NLL-Loss  277.5111, KL-Loss   79.7957, KL-Weight  0.002
# TRAIN Epoch 20/500, Mean ELBO  277.6727
# Model saved at checkpoints/2023-Dec-05-03:19:06/E20.pytorch
# VALID Batch 0000/0, Loss  275.4520, NLL-Loss  275.2878, KL-Loss   80.8672, KL-Weight  0.002
# VALID Epoch 20/500, Mean ELBO  275.4520
# TRAIN Batch 0000/0, Loss  276.2906, NLL-Loss  276.1264, KL-Loss   80.8672, KL-Weight  0.002
# TRAIN Epoch 21/500, Mean ELBO  276.2906
# Model saved at checkpoints/2023-Dec-05-03:19:06/E21.pytorch
# VALID Batch 0000/0, Loss  274.1254, NLL-Loss  273.9596, KL-Loss   81.4132, KL-Weight  0.002
# VALID Epoch 21/500, Mean ELBO  274.1254
# TRAIN Batch 0000/0, Loss  275.2435, NLL-Loss  275.0778, KL-Loss   81.4132, KL-Weight  0.002
# TRAIN Epoch 22/500, Mean ELBO  275.2435
# Model saved at checkpoints/2023-Dec-05-03:19:06/E22.pytorch
# VALID Batch 0000/0, Loss  272.7308, NLL-Loss  272.5658, KL-Loss   80.8744, KL-Weight  0.002
# VALID Epoch 22/500, Mean ELBO  272.7308
# TRAIN Batch 0000/0, Loss  273.8978, NLL-Loss  273.7327, KL-Loss   80.8744, KL-Weight  0.002
# TRAIN Epoch 23/500, Mean ELBO  273.8978
# Model saved at checkpoints/2023-Dec-05-03:19:06/E23.pytorch
# VALID Batch 0000/0, Loss  271.3731, NLL-Loss  271.2096, KL-Loss   79.9407, KL-Weight  0.002
# VALID Epoch 23/500, Mean ELBO  271.3731
# TRAIN Batch 0000/0, Loss  272.3662, NLL-Loss  272.2027, KL-Loss   79.9407, KL-Weight  0.002
# TRAIN Epoch 24/500, Mean ELBO  272.3662
# Model saved at checkpoints/2023-Dec-05-03:19:06/E24.pytorch
# VALID Batch 0000/0, Loss  269.9613, NLL-Loss  269.7974, KL-Loss   79.9097, KL-Weight  0.002
# VALID Epoch 24/500, Mean ELBO  269.9613
# TRAIN Batch 0000/0, Loss  270.9696, NLL-Loss  270.8057, KL-Loss   79.9097, KL-Weight  0.002
# TRAIN Epoch 25/500, Mean ELBO  270.9696
# Model saved at checkpoints/2023-Dec-05-03:19:06/E25.pytorch
# VALID Batch 0000/0, Loss  268.5582, NLL-Loss  268.3929, KL-Loss   80.3994, KL-Weight  0.002
# VALID Epoch 25/500, Mean ELBO  268.5582
# TRAIN Batch 0000/0, Loss  269.8147, NLL-Loss  269.6494, KL-Loss   80.3994, KL-Weight  0.002
# TRAIN Epoch 26/500, Mean ELBO  269.8147
# Model saved at checkpoints/2023-Dec-05-03:19:06/E26.pytorch
# VALID Batch 0000/0, Loss  267.2453, NLL-Loss  267.0755, KL-Loss   82.3889, KL-Weight  0.002
# VALID Epoch 26/500, Mean ELBO  267.2453
# TRAIN Batch 0000/0, Loss  268.3840, NLL-Loss  268.2142, KL-Loss   82.3889, KL-Weight  0.002
# TRAIN Epoch 27/500, Mean ELBO  268.3840
# Model saved at checkpoints/2023-Dec-05-03:19:06/E27.pytorch
# VALID Batch 0000/0, Loss  265.9680, NLL-Loss  265.7919, KL-Loss   85.2160, KL-Weight  0.002
# VALID Epoch 27/500, Mean ELBO  265.9680
# TRAIN Batch 0000/0, Loss  266.9150, NLL-Loss  266.7390, KL-Loss   85.2160, KL-Weight  0.002
# TRAIN Epoch 28/500, Mean ELBO  266.9150
# Model saved at checkpoints/2023-Dec-05-03:19:06/E28.pytorch
# VALID Batch 0000/0, Loss  264.4616, NLL-Loss  264.2759, KL-Loss   89.6839, KL-Weight  0.002
# VALID Epoch 28/500, Mean ELBO  264.4616
# TRAIN Batch 0000/0, Loss  265.8382, NLL-Loss  265.6524, KL-Loss   89.6839, KL-Weight  0.002
# TRAIN Epoch 29/500, Mean ELBO  265.8382
# Model saved at checkpoints/2023-Dec-05-03:19:06/E29.pytorch
# VALID Batch 0000/0, Loss  263.0936, NLL-Loss  262.8978, KL-Loss   94.2885, KL-Weight  0.002
# VALID Epoch 29/500, Mean ELBO  263.0936
# TRAIN Batch 0000/0, Loss  264.4003, NLL-Loss  264.2045, KL-Loss   94.2885, KL-Weight  0.002
# TRAIN Epoch 30/500, Mean ELBO  264.4003
# Model saved at checkpoints/2023-Dec-05-03:19:06/E30.pytorch
# VALID Batch 0000/0, Loss  261.7198, NLL-Loss  261.5158, KL-Loss   97.9939, KL-Weight  0.002
# VALID Epoch 30/500, Mean ELBO  261.7198
# TRAIN Batch 0000/0, Loss  262.8775, NLL-Loss  262.6735, KL-Loss   97.9939, KL-Weight  0.002
# TRAIN Epoch 31/500, Mean ELBO  262.8775
# Model saved at checkpoints/2023-Dec-05-03:19:06/E31.pytorch
# VALID Batch 0000/0, Loss  260.1149, NLL-Loss  259.9013, KL-Loss  102.3419, KL-Weight  0.002
# VALID Epoch 31/500, Mean ELBO  260.1149
# TRAIN Batch 0000/0, Loss  261.6290, NLL-Loss  261.4155, KL-Loss  102.3419, KL-Weight  0.002
# TRAIN Epoch 32/500, Mean ELBO  261.6290
# Model saved at checkpoints/2023-Dec-05-03:19:06/E32.pytorch
# VALID Batch 0000/0, Loss  258.7404, NLL-Loss  258.5157, KL-Loss  107.4325, KL-Weight  0.002
# VALID Epoch 32/500, Mean ELBO  258.7404
# TRAIN Batch 0000/0, Loss  260.2089, NLL-Loss  259.9842, KL-Loss  107.4324, KL-Weight  0.002
# TRAIN Epoch 33/500, Mean ELBO  260.2089
# Model saved at checkpoints/2023-Dec-05-03:19:06/E33.pytorch
# VALID Batch 0000/0, Loss  257.3603, NLL-Loss  257.1257, KL-Loss  111.8789, KL-Weight  0.002
# VALID Epoch 33/500, Mean ELBO  257.3603
# TRAIN Batch 0000/0, Loss  258.5933, NLL-Loss  258.3586, KL-Loss  111.8789, KL-Weight  0.002
# TRAIN Epoch 34/500, Mean ELBO  258.5933
# Model saved at checkpoints/2023-Dec-05-03:19:06/E34.pytorch
# VALID Batch 0000/0, Loss  255.7155, NLL-Loss  255.4752, KL-Loss  114.3227, KL-Weight  0.002
# VALID Epoch 34/500, Mean ELBO  255.7155
# TRAIN Batch 0000/0, Loss  257.0186, NLL-Loss  256.7782, KL-Loss  114.3227, KL-Weight  0.002
# TRAIN Epoch 35/500, Mean ELBO  257.0186
# Model saved at checkpoints/2023-Dec-05-03:19:06/E35.pytorch
# VALID Batch 0000/0, Loss  254.1989, NLL-Loss  253.9508, KL-Loss  117.7167, KL-Weight  0.002
# VALID Epoch 35/500, Mean ELBO  254.1989
# TRAIN Batch 0000/0, Loss  255.8244, NLL-Loss  255.5763, KL-Loss  117.7167, KL-Weight  0.002
# TRAIN Epoch 36/500, Mean ELBO  255.8244
# Model saved at checkpoints/2023-Dec-05-03:19:06/E36.pytorch
# VALID Batch 0000/0, Loss  252.6538, NLL-Loss  252.3917, KL-Loss  124.0414, KL-Weight  0.002
# VALID Epoch 36/500, Mean ELBO  252.6538
# TRAIN Batch 0000/0, Loss  254.0472, NLL-Loss  253.7851, KL-Loss  124.0414, KL-Weight  0.002
# TRAIN Epoch 37/500, Mean ELBO  254.0472
# Model saved at checkpoints/2023-Dec-05-03:19:06/E37.pytorch
# VALID Batch 0000/0, Loss  251.1745, NLL-Loss  250.8960, KL-Loss  131.4546, KL-Weight  0.002
# VALID Epoch 37/500, Mean ELBO  251.1745
# TRAIN Batch 0000/0, Loss  252.6392, NLL-Loss  252.3608, KL-Loss  131.4546, KL-Weight  0.002
# TRAIN Epoch 38/500, Mean ELBO  252.6392
# Model saved at checkpoints/2023-Dec-05-03:19:06/E38.pytorch
# VALID Batch 0000/0, Loss  249.8004, NLL-Loss  249.5053, KL-Loss  138.9497, KL-Weight  0.002
# VALID Epoch 38/500, Mean ELBO  249.8004
# TRAIN Batch 0000/0, Loss  251.2261, NLL-Loss  250.9310, KL-Loss  138.9496, KL-Weight  0.002
# TRAIN Epoch 39/500, Mean ELBO  251.2261
# Model saved at checkpoints/2023-Dec-05-03:19:06/E39.pytorch
# VALID Batch 0000/0, Loss  248.2712, NLL-Loss  247.9603, KL-Loss  146.0341, KL-Weight  0.002
# VALID Epoch 39/500, Mean ELBO  248.2712
# TRAIN Batch 0000/0, Loss  249.9264, NLL-Loss  249.6155, KL-Loss  146.0341, KL-Weight  0.002
# TRAIN Epoch 40/500, Mean ELBO  249.9264
# Model saved at checkpoints/2023-Dec-05-03:19:06/E40.pytorch
# VALID Batch 0000/0, Loss  246.6673, NLL-Loss  246.3405, KL-Loss  153.1294, KL-Weight  0.002
# VALID Epoch 40/500, Mean ELBO  246.6673
# TRAIN Batch 0000/0, Loss  247.9649, NLL-Loss  247.6381, KL-Loss  153.1294, KL-Weight  0.002
# TRAIN Epoch 41/500, Mean ELBO  247.9649
# Model saved at checkpoints/2023-Dec-05-03:19:06/E41.pytorch
# VALID Batch 0000/0, Loss  245.1238, NLL-Loss  244.7807, KL-Loss  160.3588, KL-Weight  0.002
# VALID Epoch 41/500, Mean ELBO  245.1238
# TRAIN Batch 0000/0, Loss  246.5282, NLL-Loss  246.1851, KL-Loss  160.3588, KL-Weight  0.002
# TRAIN Epoch 42/500, Mean ELBO  246.5282
# Model saved at checkpoints/2023-Dec-05-03:19:06/E42.pytorch
# VALID Batch 0000/0, Loss  243.4852, NLL-Loss  243.1257, KL-Loss  167.5739, KL-Weight  0.002
# VALID Epoch 42/500, Mean ELBO  243.4852
# TRAIN Batch 0000/0, Loss  245.0692, NLL-Loss  244.7098, KL-Loss  167.5739, KL-Weight  0.002
# TRAIN Epoch 43/500, Mean ELBO  245.0692
# Model saved at checkpoints/2023-Dec-05-03:19:06/E43.pytorch
# VALID Batch 0000/0, Loss  241.9790, NLL-Loss  241.6014, KL-Loss  175.6046, KL-Weight  0.002
# VALID Epoch 43/500, Mean ELBO  241.9790
# TRAIN Batch 0000/0, Loss  243.6386, NLL-Loss  243.2610, KL-Loss  175.6046, KL-Weight  0.002
# TRAIN Epoch 44/500, Mean ELBO  243.6386
# Model saved at checkpoints/2023-Dec-05-03:19:06/E44.pytorch
# VALID Batch 0000/0, Loss  240.3419, NLL-Loss  239.9458, KL-Loss  183.7778, KL-Weight  0.002
# VALID Epoch 44/500, Mean ELBO  240.3419
# TRAIN Batch 0000/0, Loss  242.0177, NLL-Loss  241.6215, KL-Loss  183.7777, KL-Weight  0.002
# TRAIN Epoch 45/500, Mean ELBO  242.0177
# Model saved at checkpoints/2023-Dec-05-03:19:06/E45.pytorch
# VALID Batch 0000/0, Loss  238.8027, NLL-Loss  238.3884, KL-Loss  191.7363, KL-Weight  0.002
# VALID Epoch 45/500, Mean ELBO  238.8027
# TRAIN Batch 0000/0, Loss  240.6045, NLL-Loss  240.1902, KL-Loss  191.7363, KL-Weight  0.002
# TRAIN Epoch 46/500, Mean ELBO  240.6045
# Model saved at checkpoints/2023-Dec-05-03:19:06/E46.pytorch
# VALID Batch 0000/0, Loss  237.3214, NLL-Loss  236.8864, KL-Loss  200.8067, KL-Weight  0.002
# VALID Epoch 46/500, Mean ELBO  237.3214
# TRAIN Batch 0000/0, Loss  238.4476, NLL-Loss  238.0126, KL-Loss  200.8067, KL-Weight  0.002
# TRAIN Epoch 47/500, Mean ELBO  238.4476
# Model saved at checkpoints/2023-Dec-05-03:19:06/E47.pytorch
# VALID Batch 0000/0, Loss  235.6815, NLL-Loss  235.2271, KL-Loss  209.2395, KL-Weight  0.002
# VALID Epoch 47/500, Mean ELBO  235.6815
# TRAIN Batch 0000/0, Loss  237.4628, NLL-Loss  237.0083, KL-Loss  209.2395, KL-Weight  0.002
# TRAIN Epoch 48/500, Mean ELBO  237.4628
# Model saved at checkpoints/2023-Dec-05-03:19:06/E48.pytorch
# VALID Batch 0000/0, Loss  234.0002, NLL-Loss  233.5240, KL-Loss  218.6966, KL-Weight  0.002
# VALID Epoch 48/500, Mean ELBO  234.0002
# TRAIN Batch 0000/0, Loss  235.6026, NLL-Loss  235.1264, KL-Loss  218.6966, KL-Weight  0.002
# TRAIN Epoch 49/500, Mean ELBO  235.6026
# Model saved at checkpoints/2023-Dec-05-03:19:06/E49.pytorch
# VALID Batch 0000/0, Loss  232.4357, NLL-Loss  231.9417, KL-Loss  226.3365, KL-Weight  0.002
# VALID Epoch 49/500, Mean ELBO  232.4357
# TRAIN Batch 0000/0, Loss  234.2129, NLL-Loss  233.7189, KL-Loss  226.3366, KL-Weight  0.002
# TRAIN Epoch 50/500, Mean ELBO  234.2129
# Model saved at checkpoints/2023-Dec-05-03:19:06/E50.pytorch
# VALID Batch 0000/0, Loss  230.7041, NLL-Loss  230.1940, KL-Loss  233.1299, KL-Weight  0.002
# VALID Epoch 50/500, Mean ELBO  230.7041
# TRAIN Batch 0000/0, Loss  232.8179, NLL-Loss  232.3078, KL-Loss  233.1299, KL-Weight  0.002
# TRAIN Epoch 51/500, Mean ELBO  232.8179
# Model saved at checkpoints/2023-Dec-05-03:19:06/E51.pytorch
# VALID Batch 0000/0, Loss  229.0836, NLL-Loss  228.5530, KL-Loss  241.9028, KL-Weight  0.002
# VALID Epoch 51/500, Mean ELBO  229.0836
# TRAIN Batch 0000/0, Loss  231.1394, NLL-Loss  230.6088, KL-Loss  241.9028, KL-Weight  0.002
# TRAIN Epoch 52/500, Mean ELBO  231.1394
# Model saved at checkpoints/2023-Dec-05-03:19:06/E52.pytorch
# VALID Batch 0000/0, Loss  227.6037, NLL-Loss  227.0499, KL-Loss  251.8400, KL-Weight  0.002
# VALID Epoch 52/500, Mean ELBO  227.6037
# TRAIN Batch 0000/0, Loss  229.4700, NLL-Loss  228.9162, KL-Loss  251.8400, KL-Weight  0.002
# TRAIN Epoch 53/500, Mean ELBO  229.4700
# Model saved at checkpoints/2023-Dec-05-03:19:06/E53.pytorch
# VALID Batch 0000/0, Loss  225.8815, NLL-Loss  225.3007, KL-Loss  263.4800, KL-Weight  0.002
# VALID Epoch 53/500, Mean ELBO  225.8815
# TRAIN Batch 0000/0, Loss  228.0527, NLL-Loss  227.4719, KL-Loss  263.4800, KL-Weight  0.002
# TRAIN Epoch 54/500, Mean ELBO  228.0527
# Model saved at checkpoints/2023-Dec-05-03:19:06/E54.pytorch
# VALID Batch 0000/0, Loss  224.3509, NLL-Loss  223.7482, KL-Loss  272.6879, KL-Weight  0.002
# VALID Epoch 54/500, Mean ELBO  224.3509
# TRAIN Batch 0000/0, Loss  226.3598, NLL-Loss  225.7572, KL-Loss  272.6879, KL-Weight  0.002
# TRAIN Epoch 55/500, Mean ELBO  226.3598
# Model saved at checkpoints/2023-Dec-05-03:19:06/E55.pytorch
# VALID Batch 0000/0, Loss  222.6617, NLL-Loss  222.0399, KL-Loss  280.6536, KL-Weight  0.002
# VALID Epoch 55/500, Mean ELBO  222.6617
# TRAIN Batch 0000/0, Loss  224.6355, NLL-Loss  224.0137, KL-Loss  280.6536, KL-Weight  0.002
# TRAIN Epoch 56/500, Mean ELBO  224.6355
# Model saved at checkpoints/2023-Dec-05-03:19:06/E56.pytorch
# VALID Batch 0000/0, Loss  220.9234, NLL-Loss  220.2808, KL-Loss  289.3520, KL-Weight  0.002
# VALID Epoch 56/500, Mean ELBO  220.9234
# TRAIN Batch 0000/0, Loss  222.8987, NLL-Loss  222.2560, KL-Loss  289.3520, KL-Weight  0.002
# TRAIN Epoch 57/500, Mean ELBO  222.8987
# Model saved at checkpoints/2023-Dec-05-03:19:06/E57.pytorch
# VALID Batch 0000/0, Loss  219.4574, NLL-Loss  218.7942, KL-Loss  297.8386, KL-Weight  0.002
# VALID Epoch 57/500, Mean ELBO  219.4574
# TRAIN Batch 0000/0, Loss  221.5926, NLL-Loss  220.9294, KL-Loss  297.8386, KL-Weight  0.002
# TRAIN Epoch 58/500, Mean ELBO  221.5926
# Model saved at checkpoints/2023-Dec-05-03:19:06/E58.pytorch
# VALID Batch 0000/0, Loss  217.6266, NLL-Loss  216.9486, KL-Loss  303.7027, KL-Weight  0.002
# VALID Epoch 58/500, Mean ELBO  217.6266
# TRAIN Batch 0000/0, Loss  219.7311, NLL-Loss  219.0531, KL-Loss  303.7027, KL-Weight  0.002
# TRAIN Epoch 59/500, Mean ELBO  219.7311
# Model saved at checkpoints/2023-Dec-05-03:19:06/E59.pytorch
# VALID Batch 0000/0, Loss  216.2085, NLL-Loss  215.5066, KL-Loss  313.6865, KL-Weight  0.002
# VALID Epoch 59/500, Mean ELBO  216.2085
# TRAIN Batch 0000/0, Loss  218.6919, NLL-Loss  217.9899, KL-Loss  313.6865, KL-Weight  0.002
# TRAIN Epoch 60/500, Mean ELBO  218.6919
# Model saved at checkpoints/2023-Dec-05-03:19:06/E60.pytorch
# VALID Batch 0000/0, Loss  214.5490, NLL-Loss  213.8157, KL-Loss  326.8753, KL-Weight  0.002
# VALID Epoch 60/500, Mean ELBO  214.5490
# TRAIN Batch 0000/0, Loss  216.6762, NLL-Loss  215.9429, KL-Loss  326.8753, KL-Weight  0.002
# TRAIN Epoch 61/500, Mean ELBO  216.6762
# Model saved at checkpoints/2023-Dec-05-03:19:06/E61.pytorch
# VALID Batch 0000/0, Loss  212.7963, NLL-Loss  212.0409, KL-Loss  335.8990, KL-Weight  0.002
# VALID Epoch 61/500, Mean ELBO  212.7963
# TRAIN Batch 0000/0, Loss  214.7772, NLL-Loss  214.0217, KL-Loss  335.8990, KL-Weight  0.002
# TRAIN Epoch 62/500, Mean ELBO  214.7772
# Model saved at checkpoints/2023-Dec-05-03:19:06/E62.pytorch
# VALID Batch 0000/0, Loss  211.0527, NLL-Loss  210.2786, KL-Loss  343.3677, KL-Weight  0.002
# VALID Epoch 62/500, Mean ELBO  211.0527
# TRAIN Batch 0000/0, Loss  213.3346, NLL-Loss  212.5605, KL-Loss  343.3677, KL-Weight  0.002
# TRAIN Epoch 63/500, Mean ELBO  213.3346
# Model saved at checkpoints/2023-Dec-05-03:19:06/E63.pytorch
# VALID Batch 0000/0, Loss  209.5625, NLL-Loss  208.7642, KL-Loss  353.1898, KL-Weight  0.002
# VALID Epoch 63/500, Mean ELBO  209.5625
# TRAIN Batch 0000/0, Loss  212.1314, NLL-Loss  211.3331, KL-Loss  353.1898, KL-Weight  0.002
# TRAIN Epoch 64/500, Mean ELBO  212.1314
# Model saved at checkpoints/2023-Dec-05-03:19:06/E64.pytorch
# VALID Batch 0000/0, Loss  207.9328, NLL-Loss  207.1093, KL-Loss  363.4296, KL-Weight  0.002
# VALID Epoch 64/500, Mean ELBO  207.9328
# TRAIN Batch 0000/0, Loss  210.5023, NLL-Loss  209.6788, KL-Loss  363.4296, KL-Weight  0.002
# TRAIN Epoch 65/500, Mean ELBO  210.5023
# Model saved at checkpoints/2023-Dec-05-03:19:06/E65.pytorch
# VALID Batch 0000/0, Loss  206.4094, NLL-Loss  205.5598, KL-Loss  374.0001, KL-Weight  0.002
# VALID Epoch 65/500, Mean ELBO  206.4094
# TRAIN Batch 0000/0, Loss  208.7844, NLL-Loss  207.9348, KL-Loss  374.0000, KL-Weight  0.002
# TRAIN Epoch 66/500, Mean ELBO  208.7844
# Model saved at checkpoints/2023-Dec-05-03:19:06/E66.pytorch
# VALID Batch 0000/0, Loss  204.6554, NLL-Loss  203.7886, KL-Loss  380.6289, KL-Weight  0.002
# VALID Epoch 66/500, Mean ELBO  204.6554
# TRAIN Batch 0000/0, Loss  207.3080, NLL-Loss  206.4412, KL-Loss  380.6289, KL-Weight  0.002
# TRAIN Epoch 67/500, Mean ELBO  207.3080
# Model saved at checkpoints/2023-Dec-05-03:19:06/E67.pytorch
# VALID Batch 0000/0, Loss  202.7286, NLL-Loss  201.8394, KL-Loss  389.4855, KL-Weight  0.002
# VALID Epoch 67/500, Mean ELBO  202.7286
# TRAIN Batch 0000/0, Loss  205.4855, NLL-Loss  204.5964, KL-Loss  389.4856, KL-Weight  0.002
# TRAIN Epoch 68/500, Mean ELBO  205.4855
# Model saved at checkpoints/2023-Dec-05-03:19:06/E68.pytorch
# VALID Batch 0000/0, Loss  201.3884, NLL-Loss  200.4687, KL-Loss  401.8372, KL-Weight  0.002
# VALID Epoch 68/500, Mean ELBO  201.3884
# TRAIN Batch 0000/0, Loss  203.9828, NLL-Loss  203.0632, KL-Loss  401.8371, KL-Weight  0.002
# TRAIN Epoch 69/500, Mean ELBO  203.9828
# Model saved at checkpoints/2023-Dec-05-03:19:06/E69.pytorch
# VALID Batch 0000/0, Loss  199.4256, NLL-Loss  198.4854, KL-Loss  409.7588, KL-Weight  0.002
# VALID Epoch 69/500, Mean ELBO  199.4256
# TRAIN Batch 0000/0, Loss  202.2914, NLL-Loss  201.3513, KL-Loss  409.7588, KL-Weight  0.002
# TRAIN Epoch 70/500, Mean ELBO  202.2914
# Model saved at checkpoints/2023-Dec-05-03:19:06/E70.pytorch
# VALID Batch 0000/0, Loss  197.8222, NLL-Loss  196.8570, KL-Loss  419.6054, KL-Weight  0.002
# VALID Epoch 70/500, Mean ELBO  197.8222
# TRAIN Batch 0000/0, Loss  200.8079, NLL-Loss  199.8428, KL-Loss  419.6054, KL-Weight  0.002
# TRAIN Epoch 71/500, Mean ELBO  200.8079
# Model saved at checkpoints/2023-Dec-05-03:19:06/E71.pytorch
# VALID Batch 0000/0, Loss  196.1785, NLL-Loss  195.1851, KL-Loss  430.8096, KL-Weight  0.002
# VALID Epoch 71/500, Mean ELBO  196.1785
# TRAIN Batch 0000/0, Loss  198.5819, NLL-Loss  197.5885, KL-Loss  430.8096, KL-Weight  0.002
# TRAIN Epoch 72/500, Mean ELBO  198.5819
# Model saved at checkpoints/2023-Dec-05-03:19:06/E72.pytorch
# VALID Batch 0000/0, Loss  194.4672, NLL-Loss  193.4500, KL-Loss  440.0618, KL-Weight  0.002
# VALID Epoch 72/500, Mean ELBO  194.4672
# TRAIN Batch 0000/0, Loss  197.1628, NLL-Loss  196.1456, KL-Loss  440.0618, KL-Weight  0.002
# TRAIN Epoch 73/500, Mean ELBO  197.1628
# Model saved at checkpoints/2023-Dec-05-03:19:06/E73.pytorch
# VALID Batch 0000/0, Loss  192.8324, NLL-Loss  191.7918, KL-Loss  449.0733, KL-Weight  0.002
# VALID Epoch 73/500, Mean ELBO  192.8324
# TRAIN Batch 0000/0, Loss  195.8312, NLL-Loss  194.7906, KL-Loss  449.0733, KL-Weight  0.002
# TRAIN Epoch 74/500, Mean ELBO  195.8312
# Model saved at checkpoints/2023-Dec-05-03:19:06/E74.pytorch
# VALID Batch 0000/0, Loss  191.0984, NLL-Loss  190.0348, KL-Loss  457.7959, KL-Weight  0.002
# VALID Epoch 74/500, Mean ELBO  191.0984
# TRAIN Batch 0000/0, Loss  194.5701, NLL-Loss  193.5066, KL-Loss  457.7959, KL-Weight  0.002
# TRAIN Epoch 75/500, Mean ELBO  194.5701
# Model saved at checkpoints/2023-Dec-05-03:19:06/E75.pytorch
# VALID Batch 0000/0, Loss  189.3250, NLL-Loss  188.2366, KL-Loss  467.3395, KL-Weight  0.002
# VALID Epoch 75/500, Mean ELBO  189.3250
# TRAIN Batch 0000/0, Loss  192.4507, NLL-Loss  191.3623, KL-Loss  467.3395, KL-Weight  0.002
# TRAIN Epoch 76/500, Mean ELBO  192.4507
# Model saved at checkpoints/2023-Dec-05-03:19:06/E76.pytorch
# VALID Batch 0000/0, Loss  188.1495, NLL-Loss  187.0263, KL-Loss  481.0393, KL-Weight  0.002
# VALID Epoch 76/500, Mean ELBO  188.1495
# TRAIN Batch 0000/0, Loss  191.5335, NLL-Loss  190.4104, KL-Loss  481.0393, KL-Weight  0.002
# TRAIN Epoch 77/500, Mean ELBO  191.5335
# Model saved at checkpoints/2023-Dec-05-03:19:06/E77.pytorch
# VALID Batch 0000/0, Loss  185.9703, NLL-Loss  184.8230, KL-Loss  490.1360, KL-Weight  0.002
# VALID Epoch 77/500, Mean ELBO  185.9703
# TRAIN Batch 0000/0, Loss  188.7029, NLL-Loss  187.5557, KL-Loss  490.1360, KL-Weight  0.002
# TRAIN Epoch 78/500, Mean ELBO  188.7029
# Model saved at checkpoints/2023-Dec-05-03:19:06/E78.pytorch
# VALID Batch 0000/0, Loss  184.2261, NLL-Loss  183.0562, KL-Loss  498.5913, KL-Weight  0.002
# VALID Epoch 78/500, Mean ELBO  184.2261
# TRAIN Batch 0000/0, Loss  187.5004, NLL-Loss  186.3305, KL-Loss  498.5913, KL-Weight  0.002
# TRAIN Epoch 79/500, Mean ELBO  187.5004
# Model saved at checkpoints/2023-Dec-05-03:19:06/E79.pytorch
# VALID Batch 0000/0, Loss  182.6478, NLL-Loss  181.4503, KL-Loss  509.0698, KL-Weight  0.002
# VALID Epoch 79/500, Mean ELBO  182.6478
# TRAIN Batch 0000/0, Loss  186.1674, NLL-Loss  184.9699, KL-Loss  509.0699, KL-Weight  0.002
# TRAIN Epoch 80/500, Mean ELBO  186.1674
# Model saved at checkpoints/2023-Dec-05-03:19:06/E80.pytorch
# VALID Batch 0000/0, Loss  181.0921, NLL-Loss  179.8657, KL-Loss  520.0555, KL-Weight  0.002
# VALID Epoch 80/500, Mean ELBO  181.0921
# TRAIN Batch 0000/0, Loss  184.4386, NLL-Loss  183.2122, KL-Loss  520.0555, KL-Weight  0.002
# TRAIN Epoch 81/500, Mean ELBO  184.4386
# Model saved at checkpoints/2023-Dec-05-03:19:06/E81.pytorch
# VALID Batch 0000/0, Loss  179.2139, NLL-Loss  177.9613, KL-Loss  529.8570, KL-Weight  0.002
# VALID Epoch 81/500, Mean ELBO  179.2139
# TRAIN Batch 0000/0, Loss  182.3633, NLL-Loss  181.1107, KL-Loss  529.8570, KL-Weight  0.002
# TRAIN Epoch 82/500, Mean ELBO  182.3633
# Model saved at checkpoints/2023-Dec-05-03:19:06/E82.pytorch
# VALID Batch 0000/0, Loss  177.6749, NLL-Loss  176.3993, KL-Loss  538.2436, KL-Weight  0.002
# VALID Epoch 82/500, Mean ELBO  177.6749
# TRAIN Batch 0000/0, Loss  180.9731, NLL-Loss  179.6974, KL-Loss  538.2436, KL-Weight  0.002
# TRAIN Epoch 83/500, Mean ELBO  180.9731
# Model saved at checkpoints/2023-Dec-05-03:19:06/E83.pytorch
# VALID Batch 0000/0, Loss  175.8714, NLL-Loss  174.5677, KL-Loss  548.7015, KL-Weight  0.002
# VALID Epoch 83/500, Mean ELBO  175.8714
# TRAIN Batch 0000/0, Loss  179.3642, NLL-Loss  178.0605, KL-Loss  548.7015, KL-Weight  0.002
# TRAIN Epoch 84/500, Mean ELBO  179.3642
# Model saved at checkpoints/2023-Dec-05-03:19:06/E84.pytorch
# VALID Batch 0000/0, Loss  174.1481, NLL-Loss  172.8113, KL-Loss  561.2635, KL-Weight  0.002
# VALID Epoch 84/500, Mean ELBO  174.1481
# TRAIN Batch 0000/0, Loss  177.7713, NLL-Loss  176.4345, KL-Loss  561.2635, KL-Weight  0.002
# TRAIN Epoch 85/500, Mean ELBO  177.7713
# Model saved at checkpoints/2023-Dec-05-03:19:06/E85.pytorch
# VALID Batch 0000/0, Loss  172.3197, NLL-Loss  170.9560, KL-Loss  571.0790, KL-Weight  0.002
# VALID Epoch 85/500, Mean ELBO  172.3197
# TRAIN Batch 0000/0, Loss  176.0632, NLL-Loss  174.6996, KL-Loss  571.0790, KL-Weight  0.002
# TRAIN Epoch 86/500, Mean ELBO  176.0632
# Model saved at checkpoints/2023-Dec-05-03:19:06/E86.pytorch
# VALID Batch 0000/0, Loss  170.6203, NLL-Loss  169.2317, KL-Loss  580.0887, KL-Weight  0.002
# VALID Epoch 86/500, Mean ELBO  170.6203
# TRAIN Batch 0000/0, Loss  174.6625, NLL-Loss  173.2739, KL-Loss  580.0887, KL-Weight  0.002
# TRAIN Epoch 87/500, Mean ELBO  174.6625
# Model saved at checkpoints/2023-Dec-05-03:19:06/E87.pytorch
# VALID Batch 0000/0, Loss  169.0503, NLL-Loss  167.6310, KL-Loss  591.4495, KL-Weight  0.002
# VALID Epoch 87/500, Mean ELBO  169.0503
# TRAIN Batch 0000/0, Loss  173.0635, NLL-Loss  171.6442, KL-Loss  591.4495, KL-Weight  0.002
# TRAIN Epoch 88/500, Mean ELBO  173.0635
# Model saved at checkpoints/2023-Dec-05-03:19:06/E88.pytorch
# VALID Batch 0000/0, Loss  167.1950, NLL-Loss  165.7517, KL-Loss  599.9732, KL-Weight  0.002
# VALID Epoch 88/500, Mean ELBO  167.1950
# TRAIN Batch 0000/0, Loss  171.5528, NLL-Loss  170.1095, KL-Loss  599.9732, KL-Weight  0.002
# TRAIN Epoch 89/500, Mean ELBO  171.5528
# Model saved at checkpoints/2023-Dec-05-03:19:06/E89.pytorch
# VALID Batch 0000/0, Loss  165.3938, NLL-Loss  163.9314, KL-Loss  606.3401, KL-Weight  0.002
# VALID Epoch 89/500, Mean ELBO  165.3938
# TRAIN Batch 0000/0, Loss  169.7303, NLL-Loss  168.2680, KL-Loss  606.3401, KL-Weight  0.002
# TRAIN Epoch 90/500, Mean ELBO  169.7303
# Model saved at checkpoints/2023-Dec-05-03:19:06/E90.pytorch
# VALID Batch 0000/0, Loss  163.6296, NLL-Loss  162.1423, KL-Loss  615.1548, KL-Weight  0.002
# VALID Epoch 90/500, Mean ELBO  163.6296
# TRAIN Batch 0000/0, Loss  168.0669, NLL-Loss  166.5796, KL-Loss  615.1548, KL-Weight  0.002
# TRAIN Epoch 91/500, Mean ELBO  168.0669
# Model saved at checkpoints/2023-Dec-05-03:19:06/E91.pytorch
# VALID Batch 0000/0, Loss  162.0984, NLL-Loss  160.5881, KL-Loss  623.1160, KL-Weight  0.002
# VALID Epoch 91/500, Mean ELBO  162.0984
# TRAIN Batch 0000/0, Loss  166.1462, NLL-Loss  164.6360, KL-Loss  623.1160, KL-Weight  0.002
# TRAIN Epoch 92/500, Mean ELBO  166.1462
# Model saved at checkpoints/2023-Dec-05-03:19:06/E92.pytorch
# VALID Batch 0000/0, Loss  160.8043, NLL-Loss  159.2652, KL-Loss  633.4239, KL-Weight  0.002
# VALID Epoch 92/500, Mean ELBO  160.8043
# TRAIN Batch 0000/0, Loss  165.1498, NLL-Loss  163.6107, KL-Loss  633.4239, KL-Weight  0.002
# TRAIN Epoch 93/500, Mean ELBO  165.1498
# Model saved at checkpoints/2023-Dec-05-03:19:06/E93.pytorch
# VALID Batch 0000/0, Loss  158.7624, NLL-Loss  157.2072, KL-Loss  638.4778, KL-Weight  0.002
# VALID Epoch 93/500, Mean ELBO  158.7624
# TRAIN Batch 0000/0, Loss  163.8007, NLL-Loss  162.2454, KL-Loss  638.4778, KL-Weight  0.002
# TRAIN Epoch 94/500, Mean ELBO  163.8007
# Model saved at checkpoints/2023-Dec-05-03:19:06/E94.pytorch
# VALID Batch 0000/0, Loss  157.9075, NLL-Loss  156.3211, KL-Loss  649.6504, KL-Weight  0.002
# VALID Epoch 94/500, Mean ELBO  157.9075
# TRAIN Batch 0000/0, Loss  162.3954, NLL-Loss  160.8090, KL-Loss  649.6504, KL-Weight  0.002
# TRAIN Epoch 95/500, Mean ELBO  162.3954
# Model saved at checkpoints/2023-Dec-05-03:19:06/E95.pytorch
# VALID Batch 0000/0, Loss  155.5842, NLL-Loss  153.9755, KL-Loss  657.1172, KL-Weight  0.002
# VALID Epoch 95/500, Mean ELBO  155.5842
# TRAIN Batch 0000/0, Loss  160.1936, NLL-Loss  158.5849, KL-Loss  657.1171, KL-Weight  0.002
# TRAIN Epoch 96/500, Mean ELBO  160.1936
# Model saved at checkpoints/2023-Dec-05-03:19:06/E96.pytorch
# VALID Batch 0000/0, Loss  154.4681, NLL-Loss  152.8330, KL-Loss  666.2539, KL-Weight  0.002
# VALID Epoch 96/500, Mean ELBO  154.4681
# TRAIN Batch 0000/0, Loss  159.2004, NLL-Loss  157.5653, KL-Loss  666.2539, KL-Weight  0.002
# TRAIN Epoch 97/500, Mean ELBO  159.2004
# Model saved at checkpoints/2023-Dec-05-03:19:06/E97.pytorch
# VALID Batch 0000/0, Loss  152.6758, NLL-Loss  151.0263, KL-Loss  670.4225, KL-Weight  0.002
# VALID Epoch 97/500, Mean ELBO  152.6758
# TRAIN Batch 0000/0, Loss  157.4373, NLL-Loss  155.7878, KL-Loss  670.4225, KL-Weight  0.002
# TRAIN Epoch 98/500, Mean ELBO  157.4373
# Model saved at checkpoints/2023-Dec-05-03:19:06/E98.pytorch
# VALID Batch 0000/0, Loss  150.7287, NLL-Loss  149.0728, KL-Loss  671.3819, KL-Weight  0.002
# VALID Epoch 98/500, Mean ELBO  150.7287
# TRAIN Batch 0000/0, Loss  155.7353, NLL-Loss  154.0793, KL-Loss  671.3819, KL-Weight  0.002
# TRAIN Epoch 99/500, Mean ELBO  155.7353
# Model saved at checkpoints/2023-Dec-05-03:19:06/E99.pytorch
# VALID Batch 0000/0, Loss  149.0294, NLL-Loss  147.3539, KL-Loss  677.5839, KL-Weight  0.002
# VALID Epoch 99/500, Mean ELBO  149.0294
# TRAIN Batch 0000/0, Loss  154.4849, NLL-Loss  152.8095, KL-Loss  677.5840, KL-Weight  0.002
# TRAIN Epoch 100/500, Mean ELBO  154.4849
# Model saved at checkpoints/2023-Dec-05-03:19:06/E100.pytorch
# VALID Batch 0000/0, Loss  148.5589, NLL-Loss  146.8587, KL-Loss  685.8799, KL-Weight  0.002
# VALID Epoch 100/500, Mean ELBO  148.5589
# TRAIN Batch 0000/0, Loss  153.0093, NLL-Loss  151.3091, KL-Loss  685.8799, KL-Weight  0.002
# TRAIN Epoch 101/500, Mean ELBO  153.0093
# Model saved at checkpoints/2023-Dec-05-03:19:06/E101.pytorch
# VALID Batch 0000/0, Loss  146.2960, NLL-Loss  144.5901, KL-Loss  686.4753, KL-Weight  0.002
# VALID Epoch 101/500, Mean ELBO  146.2960
# TRAIN Batch 0000/0, Loss  151.5224, NLL-Loss  149.8165, KL-Loss  686.4753, KL-Weight  0.002
# TRAIN Epoch 102/500, Mean ELBO  151.5224
# Model saved at checkpoints/2023-Dec-05-03:19:06/E102.pytorch
# VALID Batch 0000/0, Loss  144.6391, NLL-Loss  142.9121, KL-Loss  693.2494, KL-Weight  0.002
# VALID Epoch 102/500, Mean ELBO  144.6391
# TRAIN Batch 0000/0, Loss  149.9986, NLL-Loss  148.2716, KL-Loss  693.2494, KL-Weight  0.002
# TRAIN Epoch 103/500, Mean ELBO  149.9986
# Model saved at checkpoints/2023-Dec-05-03:19:06/E103.pytorch
# VALID Batch 0000/0, Loss  143.3288, NLL-Loss  141.5683, KL-Loss  704.9593, KL-Weight  0.002
# VALID Epoch 103/500, Mean ELBO  143.3288
# TRAIN Batch 0000/0, Loss  148.4534, NLL-Loss  146.6928, KL-Loss  704.9594, KL-Weight  0.002
# TRAIN Epoch 104/500, Mean ELBO  148.4534
# Model saved at checkpoints/2023-Dec-05-03:19:06/E104.pytorch
# VALID Batch 0000/0, Loss  141.8659, NLL-Loss  140.0810, KL-Loss  712.9498, KL-Weight  0.003
# VALID Epoch 104/500, Mean ELBO  141.8659
# TRAIN Batch 0000/0, Loss  146.7191, NLL-Loss  144.9342, KL-Loss  712.9497, KL-Weight  0.003
# TRAIN Epoch 105/500, Mean ELBO  146.7191
# Model saved at checkpoints/2023-Dec-05-03:19:06/E105.pytorch
# VALID Batch 0000/0, Loss  139.6289, NLL-Loss  137.8362, KL-Loss  714.2612, KL-Weight  0.003
# VALID Epoch 105/500, Mean ELBO  139.6289
# TRAIN Batch 0000/0, Loss  144.9590, NLL-Loss  143.1663, KL-Loss  714.2612, KL-Weight  0.003
# TRAIN Epoch 106/500, Mean ELBO  144.9590
# Model saved at checkpoints/2023-Dec-05-03:19:06/E106.pytorch
# VALID Batch 0000/0, Loss  138.4853, NLL-Loss  136.6806, KL-Loss  717.2522, KL-Weight  0.003
# VALID Epoch 106/500, Mean ELBO  138.4853
# TRAIN Batch 0000/0, Loss  143.9891, NLL-Loss  142.1844, KL-Loss  717.2522, KL-Weight  0.003
# TRAIN Epoch 107/500, Mean ELBO  143.9891
# Model saved at checkpoints/2023-Dec-05-03:19:06/E107.pytorch
# VALID Batch 0000/0, Loss  137.0430, NLL-Loss  135.2172, KL-Loss  723.8411, KL-Weight  0.003
# VALID Epoch 107/500, Mean ELBO  137.0430
# TRAIN Batch 0000/0, Loss  142.1291, NLL-Loss  140.3032, KL-Loss  723.8411, KL-Weight  0.003
# TRAIN Epoch 108/500, Mean ELBO  142.1291
# Model saved at checkpoints/2023-Dec-05-03:19:06/E108.pytorch
# VALID Batch 0000/0, Loss  135.6170, NLL-Loss  133.7654, KL-Loss  732.2229, KL-Weight  0.003
# VALID Epoch 108/500, Mean ELBO  135.6170
# TRAIN Batch 0000/0, Loss  141.0695, NLL-Loss  139.2179, KL-Loss  732.2230, KL-Weight  0.003
# TRAIN Epoch 109/500, Mean ELBO  141.0695
# Model saved at checkpoints/2023-Dec-05-03:19:06/E109.pytorch
# VALID Batch 0000/0, Loss  133.8367, NLL-Loss  131.9671, KL-Loss  737.4955, KL-Weight  0.003
# VALID Epoch 109/500, Mean ELBO  133.8367
# TRAIN Batch 0000/0, Loss  139.5455, NLL-Loss  137.6759, KL-Loss  737.4955, KL-Weight  0.003
# TRAIN Epoch 110/500, Mean ELBO  139.5455
# Model saved at checkpoints/2023-Dec-05-03:19:06/E110.pytorch
# VALID Batch 0000/0, Loss  132.3381, NLL-Loss  130.4485, KL-Loss  743.5450, KL-Weight  0.003
# VALID Epoch 110/500, Mean ELBO  132.3381
# TRAIN Batch 0000/0, Loss  138.3584, NLL-Loss  136.4687, KL-Loss  743.5450, KL-Weight  0.003
# TRAIN Epoch 111/500, Mean ELBO  138.3584
# Model saved at checkpoints/2023-Dec-05-03:19:06/E111.pytorch
# VALID Batch 0000/0, Loss  131.3926, NLL-Loss  129.4917, KL-Loss  746.1172, KL-Weight  0.003
# VALID Epoch 111/500, Mean ELBO  131.3926
# TRAIN Batch 0000/0, Loss  137.0180, NLL-Loss  135.1171, KL-Loss  746.1171, KL-Weight  0.003
# TRAIN Epoch 112/500, Mean ELBO  137.0180
# Model saved at checkpoints/2023-Dec-05-03:19:06/E112.pytorch
# VALID Batch 0000/0, Loss  129.6246, NLL-Loss  127.7209, KL-Loss  745.3315, KL-Weight  0.003
# VALID Epoch 112/500, Mean ELBO  129.6246
# TRAIN Batch 0000/0, Loss  135.1646, NLL-Loss  133.2609, KL-Loss  745.3315, KL-Weight  0.003
# TRAIN Epoch 113/500, Mean ELBO  135.1646
# Model saved at checkpoints/2023-Dec-05-03:19:06/E113.pytorch
# VALID Batch 0000/0, Loss  127.9162, NLL-Loss  126.0059, KL-Loss  746.0632, KL-Weight  0.003
# VALID Epoch 113/500, Mean ELBO  127.9162
# TRAIN Batch 0000/0, Loss  134.0628, NLL-Loss  132.1525, KL-Loss  746.0632, KL-Weight  0.003
# TRAIN Epoch 114/500, Mean ELBO  134.0628
# Model saved at checkpoints/2023-Dec-05-03:19:06/E114.pytorch
# VALID Batch 0000/0, Loss  126.4739, NLL-Loss  124.5446, KL-Loss  751.6192, KL-Weight  0.003
# VALID Epoch 114/500, Mean ELBO  126.4739
# TRAIN Batch 0000/0, Loss  132.3945, NLL-Loss  130.4652, KL-Loss  751.6193, KL-Weight  0.003
# TRAIN Epoch 115/500, Mean ELBO  132.3945
# Model saved at checkpoints/2023-Dec-05-03:19:06/E115.pytorch
# VALID Batch 0000/0, Loss  125.4234, NLL-Loss  123.4692, KL-Loss  759.4392, KL-Weight  0.003
# VALID Epoch 115/500, Mean ELBO  125.4234
# TRAIN Batch 0000/0, Loss  131.1093, NLL-Loss  129.1551, KL-Loss  759.4392, KL-Weight  0.003
# TRAIN Epoch 116/500, Mean ELBO  131.1093
# Model saved at checkpoints/2023-Dec-05-03:19:06/E116.pytorch
# VALID Batch 0000/0, Loss  123.9794, NLL-Loss  122.0089, KL-Loss  763.8291, KL-Weight  0.003
# VALID Epoch 116/500, Mean ELBO  123.9794
# TRAIN Batch 0000/0, Loss  129.9246, NLL-Loss  127.9541, KL-Loss  763.8290, KL-Weight  0.003
# TRAIN Epoch 117/500, Mean ELBO  129.9246
# Model saved at checkpoints/2023-Dec-05-03:19:06/E117.pytorch
# VALID Batch 0000/0, Loss  122.0909, NLL-Loss  120.1187, KL-Loss  762.6165, KL-Weight  0.003
# VALID Epoch 117/500, Mean ELBO  122.0909
# TRAIN Batch 0000/0, Loss  128.5563, NLL-Loss  126.5841, KL-Loss  762.6165, KL-Weight  0.003
# TRAIN Epoch 118/500, Mean ELBO  128.5563
# Model saved at checkpoints/2023-Dec-05-03:19:06/E118.pytorch
# VALID Batch 0000/0, Loss  120.5641, NLL-Loss  118.5782, KL-Loss  765.9896, KL-Weight  0.003
# VALID Epoch 118/500, Mean ELBO  120.5641
# TRAIN Batch 0000/0, Loss  127.0969, NLL-Loss  125.1110, KL-Loss  765.9896, KL-Weight  0.003
# TRAIN Epoch 119/500, Mean ELBO  127.0969
# Model saved at checkpoints/2023-Dec-05-03:19:06/E119.pytorch
# VALID Batch 0000/0, Loss  120.1701, NLL-Loss  118.1619, KL-Loss  772.6304, KL-Weight  0.003
# VALID Epoch 119/500, Mean ELBO  120.1701
# TRAIN Batch 0000/0, Loss  126.0732, NLL-Loss  124.0650, KL-Loss  772.6303, KL-Weight  0.003
# TRAIN Epoch 120/500, Mean ELBO  126.0732
# Model saved at checkpoints/2023-Dec-05-03:19:06/E120.pytorch
# VALID Batch 0000/0, Loss  117.8031, NLL-Loss  115.7866, KL-Loss  773.9178, KL-Weight  0.003
# VALID Epoch 120/500, Mean ELBO  117.8031
# TRAIN Batch 0000/0, Loss  123.9221, NLL-Loss  121.9056, KL-Loss  773.9177, KL-Weight  0.003
# TRAIN Epoch 121/500, Mean ELBO  123.9221
# Model saved at checkpoints/2023-Dec-05-03:19:06/E121.pytorch
# VALID Batch 0000/0, Loss  116.5299, NLL-Loss  114.5027, KL-Loss  776.0918, KL-Weight  0.003
# VALID Epoch 121/500, Mean ELBO  116.5299
# TRAIN Batch 0000/0, Loss  123.4540, NLL-Loss  121.4268, KL-Loss  776.0918, KL-Weight  0.003
# TRAIN Epoch 122/500, Mean ELBO  123.4540
# Model saved at checkpoints/2023-Dec-05-03:19:06/E122.pytorch
# VALID Batch 0000/0, Loss  115.5733, NLL-Loss  113.5230, KL-Loss  782.9622, KL-Weight  0.003
# VALID Epoch 122/500, Mean ELBO  115.5733
# TRAIN Batch 0000/0, Loss  122.0369, NLL-Loss  119.9867, KL-Loss  782.9622, KL-Weight  0.003
# TRAIN Epoch 123/500, Mean ELBO  122.0369
# Model saved at checkpoints/2023-Dec-05-03:19:06/E123.pytorch
# VALID Batch 0000/0, Loss  114.3589, NLL-Loss  112.2948, KL-Loss  786.2946, KL-Weight  0.003
# VALID Epoch 123/500, Mean ELBO  114.3589
# TRAIN Batch 0000/0, Loss  120.6368, NLL-Loss  118.5727, KL-Loss  786.2946, KL-Weight  0.003
# TRAIN Epoch 124/500, Mean ELBO  120.6368
# Model saved at checkpoints/2023-Dec-05-03:19:06/E124.pytorch
# VALID Batch 0000/0, Loss  112.0987, NLL-Loss  110.0319, KL-Loss  785.3685, KL-Weight  0.003
# VALID Epoch 124/500, Mean ELBO  112.0987
# TRAIN Batch 0000/0, Loss  119.5516, NLL-Loss  117.4848, KL-Loss  785.3685, KL-Weight  0.003
# TRAIN Epoch 125/500, Mean ELBO  119.5516
# Model saved at checkpoints/2023-Dec-05-03:19:06/E125.pytorch
# VALID Batch 0000/0, Loss  110.8263, NLL-Loss  108.7460, KL-Loss  788.4908, KL-Weight  0.003
# VALID Epoch 125/500, Mean ELBO  110.8263
# TRAIN Batch 0000/0, Loss  117.6102, NLL-Loss  115.5300, KL-Loss  788.4908, KL-Weight  0.003
# TRAIN Epoch 126/500, Mean ELBO  117.6102
# Model saved at checkpoints/2023-Dec-05-03:19:06/E126.pytorch
# VALID Batch 0000/0, Loss  109.7335, NLL-Loss  107.6300, KL-Loss  795.3407, KL-Weight  0.003
# VALID Epoch 126/500, Mean ELBO  109.7335
# TRAIN Batch 0000/0, Loss  116.4447, NLL-Loss  114.3411, KL-Loss  795.3407, KL-Weight  0.003
# TRAIN Epoch 127/500, Mean ELBO  116.4447
# Model saved at checkpoints/2023-Dec-05-03:19:06/E127.pytorch
# VALID Batch 0000/0, Loss  109.0755, NLL-Loss  106.9552, KL-Loss  799.6861, KL-Weight  0.003
# VALID Epoch 127/500, Mean ELBO  109.0755
# TRAIN Batch 0000/0, Loss  114.7000, NLL-Loss  112.5796, KL-Loss  799.6861, KL-Weight  0.003
# TRAIN Epoch 128/500, Mean ELBO  114.7000
# Model saved at checkpoints/2023-Dec-05-03:19:06/E128.pytorch
# VALID Batch 0000/0, Loss  107.1500, NLL-Loss  105.0233, KL-Loss  800.1118, KL-Weight  0.003
# VALID Epoch 128/500, Mean ELBO  107.1500
# TRAIN Batch 0000/0, Loss  113.6999, NLL-Loss  111.5732, KL-Loss  800.1119, KL-Weight  0.003
# TRAIN Epoch 129/500, Mean ELBO  113.6999
# Model saved at checkpoints/2023-Dec-05-03:19:06/E129.pytorch
# VALID Batch 0000/0, Loss  105.3995, NLL-Loss  103.2686, KL-Loss  799.6871, KL-Weight  0.003
# VALID Epoch 129/500, Mean ELBO  105.3995
# TRAIN Batch 0000/0, Loss  112.3242, NLL-Loss  110.1933, KL-Loss  799.6870, KL-Weight  0.003
# TRAIN Epoch 130/500, Mean ELBO  112.3242
# Model saved at checkpoints/2023-Dec-05-03:19:06/E130.pytorch
# VALID Batch 0000/0, Loss  104.1782, NLL-Loss  102.0330, KL-Loss  803.0453, KL-Weight  0.003
# VALID Epoch 130/500, Mean ELBO  104.1782
# TRAIN Batch 0000/0, Loss  111.6249, NLL-Loss  109.4797, KL-Loss  803.0453, KL-Weight  0.003
# TRAIN Epoch 131/500, Mean ELBO  111.6249
# Model saved at checkpoints/2023-Dec-05-03:19:06/E131.pytorch
# VALID Batch 0000/0, Loss  103.8791, NLL-Loss  101.7088, KL-Loss  810.4019, KL-Weight  0.003
# VALID Epoch 131/500, Mean ELBO  103.8791
# TRAIN Batch 0000/0, Loss  110.9669, NLL-Loss  108.7966, KL-Loss  810.4019, KL-Weight  0.003
# TRAIN Epoch 132/500, Mean ELBO  110.9669
# Model saved at checkpoints/2023-Dec-05-03:19:06/E132.pytorch
# VALID Batch 0000/0, Loss  101.9725, NLL-Loss   99.7921, KL-Loss  812.1720, KL-Weight  0.003
# VALID Epoch 132/500, Mean ELBO  101.9725
# TRAIN Batch 0000/0, Loss  108.4725, NLL-Loss  106.2920, KL-Loss  812.1720, KL-Weight  0.003
# TRAIN Epoch 133/500, Mean ELBO  108.4725
# Model saved at checkpoints/2023-Dec-05-03:19:06/E133.pytorch
# VALID Batch 0000/0, Loss  100.6678, NLL-Loss   98.4858, KL-Loss  810.7419, KL-Weight  0.003
# VALID Epoch 133/500, Mean ELBO  100.6678
# TRAIN Batch 0000/0, Loss  108.0075, NLL-Loss  105.8254, KL-Loss  810.7419, KL-Weight  0.003
# TRAIN Epoch 134/500, Mean ELBO  108.0075
# Model saved at checkpoints/2023-Dec-05-03:19:06/E134.pytorch
# VALID Batch 0000/0, Loss   99.4057, NLL-Loss   97.2116, KL-Loss  813.1905, KL-Weight  0.003
# VALID Epoch 134/500, Mean ELBO   99.4057
# TRAIN Batch 0000/0, Loss  106.9661, NLL-Loss  104.7720, KL-Loss  813.1905, KL-Weight  0.003
# TRAIN Epoch 135/500, Mean ELBO  106.9661
# Model saved at checkpoints/2023-Dec-05-03:19:06/E135.pytorch
# VALID Batch 0000/0, Loss   98.8400, NLL-Loss   96.6266, KL-Loss  818.3318, KL-Weight  0.003
# VALID Epoch 135/500, Mean ELBO   98.8400
# TRAIN Batch 0000/0, Loss  105.9127, NLL-Loss  103.6992, KL-Loss  818.3318, KL-Weight  0.003
# TRAIN Epoch 136/500, Mean ELBO  105.9127
# Model saved at checkpoints/2023-Dec-05-03:19:06/E136.pytorch
# VALID Batch 0000/0, Loss   97.1427, NLL-Loss   94.9252, KL-Loss  817.7773, KL-Weight  0.003
# VALID Epoch 136/500, Mean ELBO   97.1427
# TRAIN Batch 0000/0, Loss  103.8599, NLL-Loss  101.6425, KL-Loss  817.7773, KL-Weight  0.003
# TRAIN Epoch 137/500, Mean ELBO  103.8599
# Model saved at checkpoints/2023-Dec-05-03:19:06/E137.pytorch
# VALID Batch 0000/0, Loss   95.4619, NLL-Loss   93.2478, KL-Loss  814.4711, KL-Weight  0.003
# VALID Epoch 137/500, Mean ELBO   95.4619
# TRAIN Batch 0000/0, Loss  102.5644, NLL-Loss  100.3504, KL-Loss  814.4711, KL-Weight  0.003
# TRAIN Epoch 138/500, Mean ELBO  102.5644
# Model saved at checkpoints/2023-Dec-05-03:19:06/E138.pytorch
# VALID Batch 0000/0, Loss   94.2216, NLL-Loss   92.0027, KL-Loss  814.2455, KL-Weight  0.003
# VALID Epoch 138/500, Mean ELBO   94.2216
# TRAIN Batch 0000/0, Loss  102.4196, NLL-Loss  100.2007, KL-Loss  814.2455, KL-Weight  0.003
# TRAIN Epoch 139/500, Mean ELBO  102.4196
# Model saved at checkpoints/2023-Dec-05-03:19:06/E139.pytorch
# VALID Batch 0000/0, Loss   93.4081, NLL-Loss   91.1647, KL-Loss  821.1744, KL-Weight  0.003
# VALID Epoch 139/500, Mean ELBO   93.4081
# TRAIN Batch 0000/0, Loss   99.9892, NLL-Loss   97.7458, KL-Loss  821.1744, KL-Weight  0.003
# TRAIN Epoch 140/500, Mean ELBO   99.9892
# Model saved at checkpoints/2023-Dec-05-03:19:06/E140.pytorch
# VALID Batch 0000/0, Loss   92.6778, NLL-Loss   90.4154, KL-Loss  826.0427, KL-Weight  0.003
# VALID Epoch 140/500, Mean ELBO   92.6778
# TRAIN Batch 0000/0, Loss   99.5716, NLL-Loss   97.3093, KL-Loss  826.0428, KL-Weight  0.003
# TRAIN Epoch 141/500, Mean ELBO   99.5716
# Model saved at checkpoints/2023-Dec-05-03:19:06/E141.pytorch
# VALID Batch 0000/0, Loss   90.5106, NLL-Loss   88.2478, KL-Loss  824.1430, KL-Weight  0.003
# VALID Epoch 141/500, Mean ELBO   90.5106
# TRAIN Batch 0000/0, Loss   97.9494, NLL-Loss   95.6866, KL-Loss  824.1430, KL-Weight  0.003
# TRAIN Epoch 142/500, Mean ELBO   97.9494
# Model saved at checkpoints/2023-Dec-05-03:19:06/E142.pytorch
# VALID Batch 0000/0, Loss   89.5389, NLL-Loss   87.2706, KL-Loss  824.0890, KL-Weight  0.003
# VALID Epoch 142/500, Mean ELBO   89.5389
# TRAIN Batch 0000/0, Loss   97.4436, NLL-Loss   95.1753, KL-Loss  824.0890, KL-Weight  0.003
# TRAIN Epoch 143/500, Mean ELBO   97.4436
# Model saved at checkpoints/2023-Dec-05-03:19:06/E143.pytorch
# VALID Batch 0000/0, Loss   88.4078, NLL-Loss   86.1239, KL-Loss  827.7267, KL-Weight  0.003
# VALID Epoch 143/500, Mean ELBO   88.4078
# TRAIN Batch 0000/0, Loss   95.9877, NLL-Loss   93.7037, KL-Loss  827.7269, KL-Weight  0.003
# TRAIN Epoch 144/500, Mean ELBO   95.9877
# Model saved at checkpoints/2023-Dec-05-03:19:06/E144.pytorch
# VALID Batch 0000/0, Loss   87.6362, NLL-Loss   85.3333, KL-Loss  832.4915, KL-Weight  0.003
# VALID Epoch 144/500, Mean ELBO   87.6362
# TRAIN Batch 0000/0, Loss   95.3263, NLL-Loss   93.0234, KL-Loss  832.4916, KL-Weight  0.003
# TRAIN Epoch 145/500, Mean ELBO   95.3263
# Model saved at checkpoints/2023-Dec-05-03:19:06/E145.pytorch
# VALID Batch 0000/0, Loss   86.1319, NLL-Loss   83.8182, KL-Loss  834.3272, KL-Weight  0.003
# ...
# TRAIN Epoch 451/500, Mean ELBO    7.2944
# Model saved at checkpoints/2023-Dec-05-03:19:06/E451.pytorch
# VALID Batch 0000/0, Loss    5.6827, NLL-Loss    3.1465, KL-Loss  426.9235, KL-Weight  0.006
# VALID Epoch 451/500, Mean ELBO    5.6827
# TRAIN Batch 0000/0, Loss    7.4095, NLL-Loss    4.8733, KL-Loss  426.9234, KL-Weight  0.006
# TRAIN Epoch 452/500, Mean ELBO    7.4095
# Model saved at checkpoints/2023-Dec-05-03:19:06/E452.pytorch
# VALID Batch 0000/0, Loss    5.5560, NLL-Loss    3.0275, KL-Loss  424.5746, KL-Weight  0.006
# VALID Epoch 452/500, Mean ELBO    5.5560
# TRAIN Batch 0000/0, Loss    7.3552, NLL-Loss    4.8267, KL-Loss  424.5746, KL-Weight  0.006
# TRAIN Epoch 453/500, Mean ELBO    7.3552
# Model saved at checkpoints/2023-Dec-05-03:19:06/E453.pytorch
# VALID Batch 0000/0, Loss    5.5478, NLL-Loss    3.0197, KL-Loss  423.4638, KL-Weight  0.006
# VALID Epoch 453/500, Mean ELBO    5.5478
# TRAIN Batch 0000/0, Loss    7.4139, NLL-Loss    4.8857, KL-Loss  423.4638, KL-Weight  0.006
# TRAIN Epoch 454/500, Mean ELBO    7.4139
# Model saved at checkpoints/2023-Dec-05-03:19:06/E454.pytorch
# VALID Batch 0000/0, Loss    5.6281, NLL-Loss    3.0931, KL-Loss  423.5603, KL-Weight  0.006
# VALID Epoch 454/500, Mean ELBO    5.6281
# TRAIN Batch 0000/0, Loss    7.1867, NLL-Loss    4.6517, KL-Loss  423.5603, KL-Weight  0.006
# TRAIN Epoch 455/500, Mean ELBO    7.1867
# Model saved at checkpoints/2023-Dec-05-03:19:06/E455.pytorch
# VALID Batch 0000/0, Loss    5.6258, NLL-Loss    3.0861, KL-Loss  423.2894, KL-Weight  0.006
# VALID Epoch 455/500, Mean ELBO    5.6258
# TRAIN Batch 0000/0, Loss    7.1067, NLL-Loss    4.5670, KL-Loss  423.2894, KL-Weight  0.006
# TRAIN Epoch 456/500, Mean ELBO    7.1067
# Model saved at checkpoints/2023-Dec-05-03:19:06/E456.pytorch
# VALID Batch 0000/0, Loss    5.4398, NLL-Loss    2.8992, KL-Loss  422.4033, KL-Weight  0.006
# VALID Epoch 456/500, Mean ELBO    5.4398
# TRAIN Batch 0000/0, Loss    7.2266, NLL-Loss    4.6860, KL-Loss  422.4033, KL-Weight  0.006
# TRAIN Epoch 457/500, Mean ELBO    7.2266
# Model saved at checkpoints/2023-Dec-05-03:19:06/E457.pytorch
# VALID Batch 0000/0, Loss    5.5942, NLL-Loss    3.0552, KL-Loss  421.0846, KL-Weight  0.006
# VALID Epoch 457/500, Mean ELBO    5.5942
# TRAIN Batch 0000/0, Loss    7.4374, NLL-Loss    4.8983, KL-Loss  421.0846, KL-Weight  0.006
# TRAIN Epoch 458/500, Mean ELBO    7.4374
# Model saved at checkpoints/2023-Dec-05-03:19:06/E458.pytorch
# VALID Batch 0000/0, Loss    5.4770, NLL-Loss    2.9368, KL-Loss  420.2297, KL-Weight  0.006
# VALID Epoch 458/500, Mean ELBO    5.4770
# TRAIN Batch 0000/0, Loss    7.0767, NLL-Loss    4.5365, KL-Loss  420.2297, KL-Weight  0.006
# TRAIN Epoch 459/500, Mean ELBO    7.0767
# Model saved at checkpoints/2023-Dec-05-03:19:06/E459.pytorch
# VALID Batch 0000/0, Loss    5.4502, NLL-Loss    2.9097, KL-Loss  419.2333, KL-Weight  0.006
# VALID Epoch 459/500, Mean ELBO    5.4502
# TRAIN Batch 0000/0, Loss    7.1475, NLL-Loss    4.6070, KL-Loss  419.2333, KL-Weight  0.006
# TRAIN Epoch 460/500, Mean ELBO    7.1475
# Model saved at checkpoints/2023-Dec-05-03:19:06/E460.pytorch
# VALID Batch 0000/0, Loss    5.5371, NLL-Loss    3.0001, KL-Loss  417.6310, KL-Weight  0.006
# VALID Epoch 460/500, Mean ELBO    5.5371
# TRAIN Batch 0000/0, Loss    7.0915, NLL-Loss    4.5544, KL-Loss  417.6310, KL-Weight  0.006
# TRAIN Epoch 461/500, Mean ELBO    7.0915
# Model saved at checkpoints/2023-Dec-05-03:19:06/E461.pytorch
# VALID Batch 0000/0, Loss    5.5872, NLL-Loss    3.0554, KL-Loss  415.7324, KL-Weight  0.006
# VALID Epoch 461/500, Mean ELBO    5.5872
# TRAIN Batch 0000/0, Loss    7.2214, NLL-Loss    4.6895, KL-Loss  415.7324, KL-Weight  0.006
# TRAIN Epoch 462/500, Mean ELBO    7.2214
# Model saved at checkpoints/2023-Dec-05-03:19:06/E462.pytorch
# VALID Batch 0000/0, Loss    5.4399, NLL-Loss    2.9184, KL-Loss  413.0181, KL-Weight  0.006
# VALID Epoch 462/500, Mean ELBO    5.4399
# TRAIN Batch 0000/0, Loss    7.0614, NLL-Loss    4.5399, KL-Loss  413.0181, KL-Weight  0.006
# TRAIN Epoch 463/500, Mean ELBO    7.0614
# Model saved at checkpoints/2023-Dec-05-03:19:06/E463.pytorch
# VALID Batch 0000/0, Loss    5.3473, NLL-Loss    2.8325, KL-Loss  410.8907, KL-Weight  0.006
# VALID Epoch 463/500, Mean ELBO    5.3473
# TRAIN Batch 0000/0, Loss    7.0911, NLL-Loss    4.5763, KL-Loss  410.8907, KL-Weight  0.006
# TRAIN Epoch 464/500, Mean ELBO    7.0911
# Model saved at checkpoints/2023-Dec-05-03:19:06/E464.pytorch
# VALID Batch 0000/0, Loss    5.3206, NLL-Loss    2.8003, KL-Loss  410.7716, KL-Weight  0.006
# VALID Epoch 464/500, Mean ELBO    5.3206
# TRAIN Batch 0000/0, Loss    7.0715, NLL-Loss    4.5512, KL-Loss  410.7716, KL-Weight  0.006
# TRAIN Epoch 465/500, Mean ELBO    7.0715
# Model saved at checkpoints/2023-Dec-05-03:19:06/E465.pytorch
# VALID Batch 0000/0, Loss    5.3701, NLL-Loss    2.8378, KL-Loss  411.6946, KL-Weight  0.006
# VALID Epoch 465/500, Mean ELBO    5.3701
# TRAIN Batch 0000/0, Loss    7.1218, NLL-Loss    4.5896, KL-Loss  411.6946, KL-Weight  0.006
# TRAIN Epoch 466/500, Mean ELBO    7.1218
# Model saved at checkpoints/2023-Dec-05-03:19:06/E466.pytorch
# VALID Batch 0000/0, Loss    5.2994, NLL-Loss    2.7594, KL-Loss  411.9190, KL-Weight  0.006
# VALID Epoch 466/500, Mean ELBO    5.2994
# TRAIN Batch 0000/0, Loss    7.0002, NLL-Loss    4.4603, KL-Loss  411.9190, KL-Weight  0.006
# TRAIN Epoch 467/500, Mean ELBO    7.0002
# Model saved at checkpoints/2023-Dec-05-03:19:06/E467.pytorch
# VALID Batch 0000/0, Loss    5.2876, NLL-Loss    2.7522, KL-Loss  410.1526, KL-Weight  0.006
# VALID Epoch 467/500, Mean ELBO    5.2876
# TRAIN Batch 0000/0, Loss    6.9456, NLL-Loss    4.4103, KL-Loss  410.1526, KL-Weight  0.006
# TRAIN Epoch 468/500, Mean ELBO    6.9456
# Model saved at checkpoints/2023-Dec-05-03:19:06/E468.pytorch
# VALID Batch 0000/0, Loss    5.3335, NLL-Loss    2.8037, KL-Loss  408.2401, KL-Weight  0.006
# VALID Epoch 468/500, Mean ELBO    5.3335
# TRAIN Batch 0000/0, Loss    7.0342, NLL-Loss    4.5044, KL-Loss  408.2401, KL-Weight  0.006
# TRAIN Epoch 469/500, Mean ELBO    7.0342
# Model saved at checkpoints/2023-Dec-05-03:19:06/E469.pytorch
# VALID Batch 0000/0, Loss    5.3719, NLL-Loss    2.8401, KL-Loss  407.5542, KL-Weight  0.006
# VALID Epoch 469/500, Mean ELBO    5.3719
# TRAIN Batch 0000/0, Loss    6.8706, NLL-Loss    4.3387, KL-Loss  407.5542, KL-Weight  0.006
# TRAIN Epoch 470/500, Mean ELBO    6.8706
# Model saved at checkpoints/2023-Dec-05-03:19:06/E470.pytorch
# VALID Batch 0000/0, Loss    5.3177, NLL-Loss    2.7816, KL-Loss  407.2352, KL-Weight  0.006
# VALID Epoch 470/500, Mean ELBO    5.3177
# TRAIN Batch 0000/0, Loss    6.9752, NLL-Loss    4.4390, KL-Loss  407.2352, KL-Weight  0.006
# TRAIN Epoch 471/500, Mean ELBO    6.9752
# Model saved at checkpoints/2023-Dec-05-03:19:06/E471.pytorch
# VALID Batch 0000/0, Loss    5.2252, NLL-Loss    2.6887, KL-Loss  406.2903, KL-Weight  0.006
# VALID Epoch 471/500, Mean ELBO    5.2252
# TRAIN Batch 0000/0, Loss    6.7998, NLL-Loss    4.2633, KL-Loss  406.2904, KL-Weight  0.006
# TRAIN Epoch 472/500, Mean ELBO    6.7998
# Model saved at checkpoints/2023-Dec-05-03:19:06/E472.pytorch
# VALID Batch 0000/0, Loss    5.2351, NLL-Loss    2.6986, KL-Loss  405.2716, KL-Weight  0.006
# VALID Epoch 472/500, Mean ELBO    5.2351
# TRAIN Batch 0000/0, Loss    6.7792, NLL-Loss    4.2428, KL-Loss  405.2716, KL-Weight  0.006
# TRAIN Epoch 473/500, Mean ELBO    6.7792
# Model saved at checkpoints/2023-Dec-05-03:19:06/E473.pytorch
# VALID Batch 0000/0, Loss    5.2699, NLL-Loss    2.7329, KL-Loss  404.3427, KL-Weight  0.006
# VALID Epoch 473/500, Mean ELBO    5.2699
# TRAIN Batch 0000/0, Loss    6.9684, NLL-Loss    4.4315, KL-Loss  404.3427, KL-Weight  0.006
# TRAIN Epoch 474/500, Mean ELBO    6.9684
# Model saved at checkpoints/2023-Dec-05-03:19:06/E474.pytorch
# VALID Batch 0000/0, Loss    5.3073, NLL-Loss    2.7706, KL-Loss  403.2827, KL-Weight  0.006
# VALID Epoch 474/500, Mean ELBO    5.3073
# TRAIN Batch 0000/0, Loss    6.8933, NLL-Loss    4.3567, KL-Loss  403.2827, KL-Weight  0.006
# TRAIN Epoch 475/500, Mean ELBO    6.8933
# Model saved at checkpoints/2023-Dec-05-03:19:06/E475.pytorch
# VALID Batch 0000/0, Loss    5.3986, NLL-Loss    2.8677, KL-Loss  401.3795, KL-Weight  0.006
# VALID Epoch 475/500, Mean ELBO    5.3986
# TRAIN Batch 0000/0, Loss    6.8026, NLL-Loss    4.2717, KL-Loss  401.3795, KL-Weight  0.006
# TRAIN Epoch 476/500, Mean ELBO    6.8026
# Model saved at checkpoints/2023-Dec-05-03:19:06/E476.pytorch
# VALID Batch 0000/0, Loss    5.3763, NLL-Loss    2.8528, KL-Loss  399.2011, KL-Weight  0.006
# VALID Epoch 476/500, Mean ELBO    5.3763
# TRAIN Batch 0000/0, Loss    6.8285, NLL-Loss    4.3050, KL-Loss  399.2011, KL-Weight  0.006
# TRAIN Epoch 477/500, Mean ELBO    6.8285
# Model saved at checkpoints/2023-Dec-05-03:19:06/E477.pytorch
# VALID Batch 0000/0, Loss    5.2114, NLL-Loss    2.6919, KL-Loss  397.5912, KL-Weight  0.006
# VALID Epoch 477/500, Mean ELBO    5.2114
# TRAIN Batch 0000/0, Loss    6.6605, NLL-Loss    4.1410, KL-Loss  397.5912, KL-Weight  0.006
# TRAIN Epoch 478/500, Mean ELBO    6.6605
# Model saved at checkpoints/2023-Dec-05-03:19:06/E478.pytorch
# VALID Batch 0000/0, Loss    5.1495, NLL-Loss    2.6231, KL-Loss  397.6759, KL-Weight  0.006
# VALID Epoch 478/500, Mean ELBO    5.1495
# TRAIN Batch 0000/0, Loss    6.7508, NLL-Loss    4.2245, KL-Loss  397.6759, KL-Weight  0.006
# TRAIN Epoch 479/500, Mean ELBO    6.7508
# Model saved at checkpoints/2023-Dec-05-03:19:06/E479.pytorch
# VALID Batch 0000/0, Loss    5.2490, NLL-Loss    2.7153, KL-Loss  397.8418, KL-Weight  0.006
# VALID Epoch 479/500, Mean ELBO    5.2490
# TRAIN Batch 0000/0, Loss    7.0043, NLL-Loss    4.4707, KL-Loss  397.8418, KL-Weight  0.006
# TRAIN Epoch 480/500, Mean ELBO    7.0043
# Model saved at checkpoints/2023-Dec-05-03:19:06/E480.pytorch
# VALID Batch 0000/0, Loss    5.4099, NLL-Loss    2.8728, KL-Loss  397.3974, KL-Weight  0.006
# VALID Epoch 480/500, Mean ELBO    5.4099
# TRAIN Batch 0000/0, Loss    6.8636, NLL-Loss    4.3264, KL-Loss  397.3974, KL-Weight  0.006
# TRAIN Epoch 481/500, Mean ELBO    6.8636
# Model saved at checkpoints/2023-Dec-05-03:19:06/E481.pytorch
# VALID Batch 0000/0, Loss    5.3162, NLL-Loss    2.7799, KL-Loss  396.2765, KL-Weight  0.006
# VALID Epoch 481/500, Mean ELBO    5.3162
# TRAIN Batch 0000/0, Loss    6.7969, NLL-Loss    4.2606, KL-Loss  396.2765, KL-Weight  0.006
# TRAIN Epoch 482/500, Mean ELBO    6.7969
# Model saved at checkpoints/2023-Dec-05-03:19:06/E482.pytorch
# VALID Batch 0000/0, Loss    5.1385, NLL-Loss    2.6089, KL-Loss  394.2544, KL-Weight  0.006
# VALID Epoch 482/500, Mean ELBO    5.1385
# TRAIN Batch 0000/0, Loss    6.5594, NLL-Loss    4.0298, KL-Loss  394.2544, KL-Weight  0.006
# TRAIN Epoch 483/500, Mean ELBO    6.5594
# Model saved at checkpoints/2023-Dec-05-03:19:06/E483.pytorch
# VALID Batch 0000/0, Loss    5.0375, NLL-Loss    2.5147, KL-Loss  392.2274, KL-Weight  0.006
# VALID Epoch 483/500, Mean ELBO    5.0375
# TRAIN Batch 0000/0, Loss    6.7032, NLL-Loss    4.1804, KL-Loss  392.2274, KL-Weight  0.006
# TRAIN Epoch 484/500, Mean ELBO    6.7032
# Model saved at checkpoints/2023-Dec-05-03:19:06/E484.pytorch
# VALID Batch 0000/0, Loss    5.0162, NLL-Loss    2.4989, KL-Loss  390.3992, KL-Weight  0.006
# VALID Epoch 484/500, Mean ELBO    5.0162
# TRAIN Batch 0000/0, Loss    6.8489, NLL-Loss    4.3315, KL-Loss  390.3991, KL-Weight  0.006
# TRAIN Epoch 485/500, Mean ELBO    6.8489
# Model saved at checkpoints/2023-Dec-05-03:19:06/E485.pytorch
# VALID Batch 0000/0, Loss    5.0755, NLL-Loss    2.5544, KL-Loss  390.0044, KL-Weight  0.006
# VALID Epoch 485/500, Mean ELBO    5.0755
# TRAIN Batch 0000/0, Loss    6.5869, NLL-Loss    4.0658, KL-Loss  390.0044, KL-Weight  0.006
# TRAIN Epoch 486/500, Mean ELBO    6.5869
# Model saved at checkpoints/2023-Dec-05-03:19:06/E486.pytorch
# VALID Batch 0000/0, Loss    5.3616, NLL-Loss    2.8379, KL-Loss  389.4511, KL-Weight  0.006
# VALID Epoch 486/500, Mean ELBO    5.3616
# TRAIN Batch 0000/0, Loss    6.6197, NLL-Loss    4.0959, KL-Loss  389.4511, KL-Weight  0.006
# TRAIN Epoch 487/500, Mean ELBO    6.6197
# Model saved at checkpoints/2023-Dec-05-03:19:06/E487.pytorch
# VALID Batch 0000/0, Loss    5.3480, NLL-Loss    2.8314, KL-Loss  387.3902, KL-Weight  0.006
# VALID Epoch 487/500, Mean ELBO    5.3480
# TRAIN Batch 0000/0, Loss    6.7394, NLL-Loss    4.2227, KL-Loss  387.3902, KL-Weight  0.006
# TRAIN Epoch 488/500, Mean ELBO    6.7394
# Model saved at checkpoints/2023-Dec-05-03:19:06/E488.pytorch
# VALID Batch 0000/0, Loss    4.9876, NLL-Loss    2.4865, KL-Loss  384.0529, KL-Weight  0.007
# VALID Epoch 488/500, Mean ELBO    4.9876
# TRAIN Batch 0000/0, Loss    6.5451, NLL-Loss    4.0440, KL-Loss  384.0529, KL-Weight  0.007
# TRAIN Epoch 489/500, Mean ELBO    6.5451
# Model saved at checkpoints/2023-Dec-05-03:19:06/E489.pytorch
# VALID Batch 0000/0, Loss    4.9469, NLL-Loss    2.4524, KL-Loss  382.0918, KL-Weight  0.007
# VALID Epoch 489/500, Mean ELBO    4.9469
# TRAIN Batch 0000/0, Loss    6.6129, NLL-Loss    4.1183, KL-Loss  382.0918, KL-Weight  0.007
# TRAIN Epoch 490/500, Mean ELBO    6.6129
# Model saved at checkpoints/2023-Dec-05-03:19:06/E490.pytorch
# VALID Batch 0000/0, Loss    4.9653, NLL-Loss    2.4638, KL-Loss  382.2037, KL-Weight  0.007
# VALID Epoch 490/500, Mean ELBO    4.9653
# TRAIN Batch 0000/0, Loss    6.5309, NLL-Loss    4.0294, KL-Loss  382.2037, KL-Weight  0.007
# TRAIN Epoch 491/500, Mean ELBO    6.5309
# Model saved at checkpoints/2023-Dec-05-03:19:06/E491.pytorch
# VALID Batch 0000/0, Loss    5.0159, NLL-Loss    2.4998, KL-Loss  383.4764, KL-Weight  0.007
# VALID Epoch 491/500, Mean ELBO    5.0159
# TRAIN Batch 0000/0, Loss    6.6749, NLL-Loss    4.1589, KL-Loss  383.4764, KL-Weight  0.007
# TRAIN Epoch 492/500, Mean ELBO    6.6749
# Model saved at checkpoints/2023-Dec-05-03:19:06/E492.pytorch
# VALID Batch 0000/0, Loss    5.0782, NLL-Loss    2.5478, KL-Loss  384.6987, KL-Weight  0.007
# VALID Epoch 492/500, Mean ELBO    5.0782
# TRAIN Batch 0000/0, Loss    6.6632, NLL-Loss    4.1329, KL-Loss  384.6987, KL-Weight  0.007
# TRAIN Epoch 493/500, Mean ELBO    6.6632
# Model saved at checkpoints/2023-Dec-05-03:19:06/E493.pytorch
# VALID Batch 0000/0, Loss    5.0733, NLL-Loss    2.5402, KL-Loss  384.1595, KL-Weight  0.007
# VALID Epoch 493/500, Mean ELBO    5.0733
# TRAIN Batch 0000/0, Loss    6.4986, NLL-Loss    3.9655, KL-Loss  384.1595, KL-Weight  0.007
# TRAIN Epoch 494/500, Mean ELBO    6.4986
# Model saved at checkpoints/2023-Dec-05-03:19:06/E494.pytorch
# VALID Batch 0000/0, Loss    5.0710, NLL-Loss    2.5436, KL-Loss  382.3371, KL-Weight  0.007
# VALID Epoch 494/500, Mean ELBO    5.0710
# TRAIN Batch 0000/0, Loss    6.5871, NLL-Loss    4.0597, KL-Loss  382.3371, KL-Weight  0.007
# TRAIN Epoch 495/500, Mean ELBO    6.5871
# Model saved at checkpoints/2023-Dec-05-03:19:06/E495.pytorch
# VALID Batch 0000/0, Loss    4.9141, NLL-Loss    2.3990, KL-Loss  379.5379, KL-Weight  0.007
# VALID Epoch 495/500, Mean ELBO    4.9141
# TRAIN Batch 0000/0, Loss    6.4770, NLL-Loss    3.9619, KL-Loss  379.5379, KL-Weight  0.007
# TRAIN Epoch 496/500, Mean ELBO    6.4770
# Model saved at checkpoints/2023-Dec-05-03:19:06/E496.pytorch
# VALID Batch 0000/0, Loss    4.9226, NLL-Loss    2.4207, KL-Loss  376.6057, KL-Weight  0.007
# VALID Epoch 496/500, Mean ELBO    4.9226
# TRAIN Batch 0000/0, Loss    6.6616, NLL-Loss    4.1598, KL-Loss  376.6057, KL-Weight  0.007
# TRAIN Epoch 497/500, Mean ELBO    6.6616
# Model saved at checkpoints/2023-Dec-05-03:19:06/E497.pytorch
# VALID Batch 0000/0, Loss    4.8667, NLL-Loss    2.3657, KL-Loss  375.5426, KL-Weight  0.007
# VALID Epoch 497/500, Mean ELBO    4.8667
# TRAIN Batch 0000/0, Loss    6.5064, NLL-Loss    4.0054, KL-Loss  375.5426, KL-Weight  0.007
# TRAIN Epoch 498/500, Mean ELBO    6.5064
# Model saved at checkpoints/2023-Dec-05-03:19:06/E498.pytorch
# VALID Batch 0000/0, Loss    4.9878, NLL-Loss    2.4746, KL-Loss  376.4408, KL-Weight  0.007
# VALID Epoch 498/500, Mean ELBO    4.9878
# TRAIN Batch 0000/0, Loss    6.4219, NLL-Loss    3.9087, KL-Loss  376.4408, KL-Weight  0.007
# TRAIN Epoch 499/500, Mean ELBO    6.4219
# Model saved at checkpoints/2023-Dec-05-03:19:06/E499.pytorch
# VALID Batch 0000/0, Loss    5.1427, NLL-Loss    2.6128, KL-Loss  377.9872, KL-Weight  0.007
# VALID Epoch 499/500, Mean ELBO    5.1427
